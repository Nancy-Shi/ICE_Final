[13, 53, 129, 167, 375], 162: [13, 17, 21, 61, 62, 144, 148, 162, 362, 409], 159: [13, 69, 406], 165: [13, 58, 141, 157, 165, 192, 201, 208, 229, 403], 37: [13, 31, 45, 154, 184, 207, 227, 277], 257: [13, 56, 58, 209, 366, 449, 454], 175: [13, 34, 50, 60, 63, 66, 113, 173, 195, 255, 357, 432, 462], 87: [13, 50, 286, 314, 453], 249: [14, 21, 119, 194, 257, 278, 317, 366, 404, 413, 459], 86: [14, 198, 302, 361, 472], 242: [14, 266, 288, 427], 81: [15, 292], 54: [15, 171, 200, 210, 415], 61: [15, 60, 267], 262: [16, 155, 398, 439, 464], 137: [16, 22, 51, 88, 111, 127, 140, 160, 274, 425], 59: [17, 29, 56, 68, 77, 80, 120, 122, 124, 127, 158, 159, 212, 316, 456, 490], 21: [17, 80, 189, 217, 225, 281, 371, 378, 435, 478], 166: [18, 37, 40, 83, 97, 132, 159, 299, 306, 431], 118: [18, 129, 413], 48: [19, 28, 106, 118, 156, 191], 128: [20, 46, 56, 76, 106, 195, 294, 321, 348, 384, 406, 469, 470], 17: [20, 102, 119, 273, 346, 470], 182: [21, 39, 106, 120, 271, 287, 360, 463], 268: [21, 22, 60, 95, 136, 152, 176, 180, 216, 236, 258, 261, 304, 339, 363, 418, 454, 483, 493], 247: [22, 98, 102], 104: [22, 83, 131, 140, 152, 162, 169, 185, 303, 305, 339], 33: [22, 100, 341, 396], 94: [23, 46, 124, 150, 250, 302, 331, 475], 275: [23, 49, 122, 152], 254: [23, 170, 199, 271, ...

# %% [markdown]
# ## Part 2: Assign Behavior Status
# NP represents the state of no protection, while P represents the state of with protection.

# %%
def assign_protection(hypergraph, fraction_protected):
    # Get the list of nodes from the hypergraph
    nodes = list(hypergraph.nodes())

    # Calculate the number of nodes to protect
    num_nodes_to_protect = int(len(nodes) * fraction_protected)

    # Randomly choose nodes to protect
    nodes_to_protect = random.sample(nodes, num_nodes_to_protect)

    # Initialize the protection status dictionary
    protection_status = {}

    # Assign protection status to each node
    for node in nodes:
        if node in nodes_to_protect:
            protection_status[node] = "P"  # Protected node
        else:
            protection_status[node] = "N"  # Non-protected node

    #print(protection_status)

    return protection_status

# %%
# Test:
fraction_protected = 0.1
protection_status_dict = assign_protection(H2, fraction_protected)
print(protection_status_dict)
# Out:
# {0: 'N', 25: 'N', 93: 'P', 197: 'N', 293: 'N', 313: 'N', 317: 'N', 351: 'N', 370: 'N', 403: 'N', 442: 'N', 446: 'N', 480: 'N', 114: 'N', 3: 'N', 140: 'N', 1: 'N', 54: 'N', 68: 'N', 103: 'N', 142: 'N', 157: 'N', 159: 'N', 102: 'N', 109: 'N', 235: 'N', 443: 'N', 33: 'N', 52: 'N', 61: 'N', 155: 'N', 224: 'N', 300: 'N', 326: 'N', 430: 'N', 434: 'P', 472: 'N', 56: 'N', 186: 'N', 253: 'N', 257: 'N', 373: 'N', 394: 'N', 405: 'N', 499: 'N', 79: 'N', 133: 'N', 213: 'N', 221: 'P', 362: 'P', 2: 'P', 111: 'P', 130: 'N', 144: 'N', 146: 'N', 241: 'N', 281: 'N', 365: 'N', 372: 'P', 451: 'N', 497: 'N', 154: 'N', 160: 'N', 334: 'N', 345: 'N', 476: 'N', 498: 'N', 23: 'N', 60: 'N', 78: 'N', 174: 'N', 201: 'N', 209: 'N', 248: 'P', 344: 'N', 386: 'N', 455: 'P', 22: 'N', 99: 'P', 112: 'N', 118: 'N', 270: 'N', 379: 'N', 398: 'N', 85: 'N', 169: 'N', 289: 'N', 354: 'N', 461: 'N', 10: 'N', 21: 'N', 106: 'N', 163: 'N', 173: 'N', 296: 'N', 301: 'N', 319: 'N', 336: 'N', 4: 'N', 44: 'N', 47: 'N', 90: 'N', 94: 'N', 165: 'N', 181: 'N', 275: 'N', 330: 'N', 377: 'N', 413: 'P', 62: 'N', 74: 'N', 190: 'N', 192: 'N', 232: 'N', 371: 'N', 8: 'N', 80: 'N', 127: 'N', 131: 'N', 196: 'N', 215: 'N', 5: 'N', 171: 'N', 180: 'N', 198: 'N', 199: 'N', 286: 'N', 332: 'N', 335: 'N', 71: 'N', 401: 'N', 465: 'N', 105: 'N', 128: 'N', 217: 'N', 273: 'N', 280: 'N', 318: 'N', 391: 'N', 411: 'N', 6: 'N', 48: 'P', 108: 'N', 164: 'N', 41: 'N', 91: 'N', 100: 'N', 134: 'N', 310: 'N', 385: 'N', 27: 'N', 92: 'N', 206: 'N', 294: 'P', 420: 'N', 495: 'N', 7: 'N', 24: 'N', 63: 'N', 172: 'N', 228: 'N', 358: 'N', 395: 'N', 396: 'N', 435: 'P', 59: 'N', 156: 'N', 458: 'N', 166: 'N', 299: 'N', 378: 'N', 11: 'P', 304: 'N', 406: 'N', 58: 'N', 237: 'N', 305: 'N', 324: 'N', 393: 'N', 12: 'N', 19: 'N', 38: 'N', 84: 'N', 138: 'N', 328: 'N', 389: 'N', 493: 'N', 9: 'N', 20: 'N', 97: 'N', 135: 'N', 136: 'N', 175: 'N', 179: 'N', 274: 'N', 399: 'N', 101: 'N', 167: 'N', 177: 'N', 246: 'N', 314: 'N', 333: 'N', 392: 'N', 484: 'N', 18: 'N', 83: 'N', 95: 'N', 207: 'N', 223: 'N', 229: 'P', 489: 'N', 203: 'N', 219: 'N', 350: 'N', 363: 'N', 382: 'N', 494: 'N', 168: 'N', 380: 'N', 441: 'N', 447: 'N', 51: 'P', 82: 'N', 147: 'N', 191: 'N', 34: 'N', 352: 'N', 143: 'N', 151: 'P', 243: 'N', 264: 'N', 268: 'N', 89: 'P', 132: 'N', 255: 'N', 427: 'N', 428: 'N', 429: 'N', 483: 'N', 492: 'N', 285: 'N', 456: 'N', 75: 'N', 141: 'P', 231: 'N', 239: 'N', 266: 'N', 374: 'N', 452: 'P', 467: 'N', 245: 'N', 338: 'N', 414: 'N', 13: 'P', 115: 'N', 126: 'P', 150: 'P', 346: 'N', 359: 'N', 468: 'N', 423: 'N', 67: 'N', 88: 'N', 137: 'P', 282: 'N', 366: 'N', 32: 'N', 230: 'N', 438: 'N', 471: 'N', 70: 'P', 211: 'N', 309: 'N', 367: 'P', 182: 'N', 249: 'N', 388: 'N', 375: 'N', 15: 'N', 120: 'N', 184: 'N', 214: 'N', 298: 'N', 306: 'N', 421: 'N', 431: 'N', 449: 'N', 117: 'N', 152: 'N', 204: 'N', 463: 'N', 470: 'N', 96: 'N', 49: 'N', 474: 'P', 125: 'N', 148: 'N', 200: 'N', 355: 'N', 43: 'P', 424: 'N', 425: 'N', 16: 'N', 107: 'N', 129: 'P', 349: 'P', 368: 'N', 433: 'P', 254: 'N', 327: 'N', 329: 'N', 357: 'N', 369: 'N', 261: 'N', 445: 'N', 459: 'P', 53: 'N', 17: 'N', 162: 'N', 409: 'N', 69: 'N', 208: 'N', 31: 'N', 45: 'P', 227: 'N', 277: 'N', 454: 'P', 50: 'N', 66: 'N', 113: 'N', 195: 'N', 432: 'P', 462: 'P', 453: 'N', 14: 'N', 119: 'N', 194: 'N', 278: 'N', 404: 'N', 302: 
node)
                            N_corrected += 1
                            N_e_i -= inw.degree(target_node)

        # Case 12: Corrected become stifler
        else:
          if len(corrected)>0:
                new_exposure_node = np.random.choice(corrected)
                info_states[new_exposure_node] = "A"
                N_corrected -= 1
                corrected.remove(new_exposure_node)
                N_stifler += 1
                stifler.append(new_exposure_node)

  return time_record, recovered_count

# %%
# No Control single run
lam = 1/3
alp = 1/3
#omega = 1/5
#sigma = 1/10
phi = 1/5
sigma = 0
zeta_1 = 0.2 #go to not protect by information
zeta_2 = 0.2 #go to protect by information
zeta_3 = 0 #go to not protect by neighborhood behavior
zeta_4 = 0 #go to protect by neighborhood behavior
mu = 0.2
R0 = 4.0 #(assume a COVID19-like disease for the reproduction number) #2.0 # reproduction number
beta_NN = R0 * mu / division_factor
beta_PN = beta_NN * 0.2
beta_NP = beta_NN * 0.1
beta_PP = beta_NN * 0.0
n_sample = 1

#time_record, recovered_count = ICE_model_record_layer(inw, ldeg_i, ltre, cnw, ldeg_c, lprot, enw, ldeg_e, lam, alp, omega, sigma, zeta_1, zeta_2, zeta_3, zeta_4, beta_PP, beta_NP, beta_PN, beta_NN, mu, n_sample)

#plt.plot(time_record, recovered_count)
#plt.xlabel(r'Time', fontsize=14)
#plt.ylabel(r'Number of recovered', fontsize=14)

#recovered_count[-1]

# %%
n_iterations = 100
# Define the range for omega and sigma
#omega_range = sigma_range = [i * 0.1 for i in range(5)]

omega_range = np.round([i * 0.20 for i in range(11)], 2)
alp2_range = np.round([i * 0.05 for i in range(11)], 2)

# Initialize data for heatmap
heatmap_data = np.zeros((len(omega_range), len(alp2_range)))

# Iterate over omega and sigma combinations
for i, omega in enumerate(omega_range):
    for j, alp2 in enumerate(alp2_range):
        recovered_counts = []

        for _ in range(n_iterations):
            time_record, recovered_count = ICE_model_record_layer_WhatsApp_C_to_A(inw, ldeg_i, ltre, cnw, ldeg_c, lprot, enw, ldeg_e, lam, alp, omega, sigma, phi, alp2, zeta_1, zeta_2, zeta_3, zeta_4, beta_PP, beta_NP, beta_PN, beta_NN, mu, n_sample)

            final_recovered_count = recovered_count[-1]
            recovered_counts.append(final_recovered_count)

        attack_rate = np.mean(recovered_counts)/500
        heatmap_data[i, j] = attack_rate

        print(f"Omega: {omega}, Alp2: {alp2}, Attack Rate: {attack_rate}")

# Store data
import csv
file_path = '/content/drive/My Drive/Information_Behavior_Disease_Networks/heat_map_results/Heatmap_WhatsApp_C_to_A.csv'
with open(file_path, 'w', newline='') as file:
    writer = csv.writer(file)

    # Write the header row with omega values
    header = ['Omega \\ Alp2'] + alp2_range.tolist()
    writer.writerow(header)

    # Write the data rows
    for i, omega in enumerate(omega_range):
        row = [omega] + heatmap_data[i].tolist()
        writer.writerow(row)

print(f"Data has been written.")
# Out:
# Omega: 0.0, Alp2: 0.0, Attack Rate: 0.10296
# Omega: 0.0, Alp2: 0.05, Attack Rate: 0.09958
# Omega: 0.0, Alp2: 0.1, Attack Rate: 0.10296
# Omega: 0.0, Alp2: 0.15, Attack Rate: 0.10502
# Omega: 0.0, Alp2: 0.2, Attack Rate: 0.09976
# Omega: 0.0, Alp2: 0.25, Attack Rate: 0.10426
# Omega: 0.0, Alp2: 0.3, Attack Rate: 0.10158
# Omega: 0.0, Alp2: 0.35, Attack Rate: 0.10008
# Omega: 0.0, Alp2: 0.4, Attack Rate: 0.1017
# Omega: 0.0, Alp2: 0.45, Attack Rate: 0.10152
# Omega: 0.0, Alp2: 0.5, Attack Rate: 0.09978000000000001
# Omega: 0.2, Alp2: 0.0, Attack Rate: 0.1013
# Omega: 0.2, Alp2: 0.05, Attack Rate: 0.10354000000000001
# Omega: 0.2, Alp2: 0.1, Attack Rate: 0.10538
# Omega: 0.2, Alp2: 0.15, Attack Rate: 0.10012
# Omega: 0.2, Alp2: 0.2, Attack Rate: 0.10038
# Omega: 0.2, Alp2: 0.25, Attack Rate: 0.0952
# Omega: 0.2, Alp2: 0.3, Attack Rate: 0.09132
# Omega: 0.2, Alp2: 0.35, Attack Rate: 0.10601999999999999
# Omega: 0.2, Alp2: 0.4, Attack Rate: 0.10394
# Omega: 0.2, Alp2: 0.45, Attack Rate: 0.09868
# Omega: 0.2, Alp2: 0.5, Attack Rate: 0.09662000000000001
# Omega: 0.4, Alp2: 0.0, Attack Rate: 0.10446
# Omega: 0.4, Alp2: 0.05, Attack Rate: 0.10654000000000001
# Omega: 0.4, Alp2: 0.1, Attack Rate: 0.09916
# Omega: 0.4, Alp2: 0.15, Attack Rate: 0.1025
# Omega: 0.4, Alp2: 0.2, Attack Rate: 0.09976
# Omega: 0.4, Alp2: 0.25, Attack Rate: 0.10490000000000001
# Omega: 0.4, Alp2: 0.3, Attack Rate: 0.10144
# Omega: 0.4, Alp2: 0.35, Attack Rate: 0.09768
# Omega: 0.4, Alp2: 0.4, Attack Rate: 0.09944
# Omega: 0.4, Alp2: 0.45, Attack Rate: 0.10601999999999999
# Omega: 0.4, Alp2: 0.5, Attack Rate: 0.09334
# Omega: 0.6, Alp2: 0.0, Attack Rate: 0.10823999999999999
# Omega: 0.6, Alp2: 0.05, Attack Rate: 0.10956
# Omega: 0.6, Alp2: 0.1, Attack Rate: 0.10042
# Omega: 0.6, Alp2: 0.15, Attack Rate: 0.1024
# Omega: 0.6, Alp2: 0.2, Attack Rate: 0.10036
# Omega: 0.6, Alp2: 0.25, Attack Rate: 0.10548
# Omega: 0.6, Alp2: 0.3, Attack Rate: 0.09456
# Omega: 0.6, Alp2: 0.35, Attack Rate: 0.09604
# Omega: 0.6, Alp2: 0.4, Attack Rate: 0.10286
# Omega: 0.6, Alp2: 0.45, Attack Rate: 0.09568
# Omega: 0.6, Alp2: 0.5, Attack Rate: 0.10406
# Omega: 0.8, Alp2: 0.0, Attack Rate: 0.11462
# Omega: 0.8, Alp2: 0.05, Attack Rate: 0.10558
# Omega: 0.8, Alp2: 0.1, Attack Rate: 0.10674
# Omega: 0.8, Alp2: 0.15, Attack Rate: 0.10422
# Omega: 0.8, Alp2: 0.2, Attack Rate: 0.0979
# Omega: 0.8, Alp2: 0.25, Attack Rate: 0.10226
# Omega: 0.8, Alp2: 0.3, Attack Rate: 0.10196
# Omega: 0.8, Alp2: 0.35, Attack Rate: 0.10696
# Omega: 0.8, Alp2: 0.4, Attack Rate: 0.0996
# Omega: 0.8, Alp2: 0.45, Attack Rate: 0.10024
# Omega: 0.8, Alp2: 0.5, Attack Rate: 0.1026
# Omega: 1.0, Alp2: 0.0, Attack Rate: 0.11273999999999999
# Omega: 1.0, Alp2: 0.05, Attack Rate: 0.11398
# Omega: 1.0, Alp2: 0.1, Attack Rate: 0.10276
# Omega: 1.0, Alp2: 0.15, Attack Rate: 0.11148000000000001
# Omega: 1.0, Alp2: 0.2, Attack Rate: 0.10378
# Omega: 1.0, Alp2: 0.25, Attack Rate: 0.09788
# Omega: 1.0, Alp2: 0.3, Attack Rate: 0.10840000000000001
# Omega: 1.0, Alp2: 0.35, Attack Rate: 0.1019
# Omega: 1.0, Alp2: 0.4, Attack Rate: 0.09862
# Omega: 1.0, Alp2: 0.45, Attack Rate: 0.09926
# Omega: 1.0, Alp2: 0.5, Attack Rate: 0.10094
# Omega: 1.2, Alp2: 0.0, Attack Rate: 0.11438
# Omega: 1.2, Alp2: 0.05, Attack Rate: 0.11392000000000001
# Omega: 1.2, Alp2: 0.1, Attack Rate: 0.10978
# Omega: 1.2, Alp2: 0.15, Attack Rate: 0.10168
# Omega: 1.2, Alp2: 0.2, Attack Rate: 0.10256
# Omega: 1.2, Alp2: 0.25, Attack Rate: 0.10632
# Omega: 1.2, Alp2: 0.3, Attack Rate: 0.1019
# Omega: 1.2, Alp2: 0.35, Attack Rate: 0.10282
# Omega: 1.2, Alp2: 0.4, Attack Rate: 0.10682
# Omega: 1.2, Alp2: 0.45, Attack Rate: 0.10321999999999999
# Omega: 1.2, Alp2: 0.5, Attack Rate: 0.10074
# Omega: 1.4, Alp2: 0.0, Attack Rate: 0.12359999999999999
# Omega: 1.4, Alp2: 0.05, Attack Rate: 0.11478000000000001
# Omega: 1.4, Alp2: 0.1, Attack Rate: 0.11098000000000001
# Omega: 1.4, Alp2: 0.15, Attack Rate: 0.10348
# Omega: 1.4, Alp2: 0.2, Attack Rate: 0.09931999999999999
# Omega: 1.4, Alp2: 0.25, Attack Rate: 0.1051
# Omega: 1.4, Alp2: 0.3, Attack Rate: 0.1055
# Omega: 1.4, Alp2: 0.35, Attack Rate: 0.09662000000000001
# Omega: 1.4, Alp2: 0.4, Attack Rate: 0.10184
# Omega: 1.4, Alp2: 0.45, Attack Rate: 0.10493999999999999
# Omega: 1.4, Alp2: 0.5, Attack Rate: 0.09934
# Omega: 1.6, Alp2: 0.0, Attack Rate: 0.12364
# Omega: 1.6, Alp2: 0.05, Attack Rate: 0.11834
# Omega: 1.6, Alp2: 0.1, Attack Rate: 0.11531999999999999
# Omega: 1.6, Alp2: 0.15, Attack Rate: 0.1151
# Omega: 1.6, Alp2: 0.2, Attack Rate: 0.1025
# Omega: 1.6, Alp2: 0.25, Attack Rate: 0.10416
# Omega: 1.6, Alp2: 0.3, Attack Rate: 0.1017
# Omega: 1.6, Alp2: 0.35, Attack Rate: 0.09684000000000001
# Omega: 1.6, Alp2: 0.4, Attack Rate: 0.10134
# Omega: 1.6, Alp2: 0.45, Attack Rate: 0.09587999999999999
# Omega: 1.6, Alp2: 0.5, Attack Rate: 0.09864
# Omega: 1.8, Alp2: 0.0, Attack Rate: 0.12356
# Omega: 1.8, Alp2: 0.05, Attack Rate: 0.1185
# Omega: 1.8, Alp2: 0.1, Attack Rate: 0.11068
# Omega: 1.8, Alp2: 0.15, Attack Rate: 0.10615999999999999
# Omega: 1.8, Alp2: 0.2, Attack Rate: 0.10578
# Omega: 1.8, Alp2: 0.25, Attack Rate: 0.1036
# Omega: 1.8, Alp2: 0.3, Attack Rate: 0.09981999999999999
# Omega: 1.8, Alp2: 0.35, Attack Rate: 0.09809999999999999
# Omega: 1.8, Alp2: 0.4, Attack Rate: 0.0999
# Omega: 1.8, Alp2: 0.45, Attack Rate: 0.09709999999999999
# Omega: 1.8, Alp2: 0.5, Attack Rate: 0.10404000000000001
# Omega: 2.0, Alp2: 0.0, Attack Rate: 0.1165
# Omega: 2.0, Alp2: 0.05, Attack Rate: 0.118
# Omega: 2.0, Alp2: 0.1, Attack Rate: 0.1205
# Omega: 2.0, Alp2: 0.15, Attack Rate: 0.1103
# Omega: 2.0, Alp2: 0.2, Attack Rate: 0.106
# Omega: 2.0, Alp2: 0.25, Attack Rate: 0.10176
# Omega: 2.0, Alp2: 0.3, Attack Rate: 0.09974
# Omega: 2.0, Alp2: 0.35, Attack Rate: 0.10446
# Omega: 2.0, Alp2: 0.4, Attack Rate: 0.1014
# Omega: 2.0, Alp2: 0.45, Attack Rate: 0.09931999999999999
# Omega: 2.0, Alp2: 0.5, Attack Rate: 0.09788
# Data has been written.

# %%
df = pd.read_csv('/content/drive/My Drive/Information_Behavior_Disease_Networks/heat_map_results/Heatmap_WhatsApp_C_to_A.csv', header = 0)

omega_range = df.columns[1:].astype(float)
alp2_range = df.iloc[:, 0].astype(float)

sparse_yticks = np.arange(0, len(omega_range), 2)
sparse_xticks = np.arange(0, len(alp2_range), 2)

sparse_ytick_labels = omega_range[::2]
sparse_xtick_labels = alp2_range[::2]

heatmap_data = df.iloc[:, 1:].values

plt.figure(figsize=(8, 6))
plt.xlabel('Rate for New Gossip ($\\omega$)', fontsize=16)
plt.ylabel('Correction Rate of Gossip ($\\alpha_2$)', fontsize=16)
plt.imshow(heatmap_data.T, cmap='plasma', interpolation='bicubic')
cbar = plt.colorbar()
cbar.set_label('Attack Rate', fontsize=16)
cbar.ax.tick_params(labelsize=14)
plt.xticks(sparse_xticks, sparse_xtick_labels, fontsize=14)
plt.yticks(sparse_yticks, sparse_ytick_labels, fontsize=14)
plt.gca().invert_yaxis()
plt.tight_layout()

plt.savefig('/content/drive/My Drive/Information_Behavior_Disease_Networks/heat_map_results/Heatmap_WhatsApp_C_to_A.pdf')

# %%
from matplotlib.ticker import FormatStrFormatter
# Load dataset
df1 = pd.read_csv('/content/drive/My Drive/Information_Behavior_Disease_Networks/heat_map_results/Heatmap_WhatsApp_C_to_A.csv', header = 0)
results_rho_R1 = df1.to_numpy()

df2 = pd.read_csv('/content/drive/My Drive/Information_Behavior_Disease_Networks/heat_map_results/Heatmap_Twitter_C_to_A.csv', header = 0)
results_rho_R2 = df2.to_numpy()

omega_range = np.round([i * 0.20 for i in range(11)], 2)
alp2_range = np.round([i * 0.05 for i in range(11)], 2)

# Create a figure with two subplots
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(12, 5))

im1 = ax1.imshow(results_rho_R1[:, 1:].T, cmap='rainbow', aspect='auto', origin='lower',
                 extent=[min(omega_range), max(omega_range), min(alp2_range), max(alp2_range)],
                 interpolation='bicubic')
ax1.set_xlabel('Rate for New Gossip ($\\omega$)', fontsize=14)
ax1.set_ylabel('Correction Rate of Gossip ($\\alpha_2$)', fontsize=14)
cbar1 = plt.colorbar(im1, ax=ax1)
cbar1.set_label('Attack Rate', fontsize=14)
cbar1.ax.tick_params(labelsize=14)
cbar1.ax.yaxis.set_major_formatter(FormatStrFormatter('%.3f'))

im2 = ax2.imshow(results_rho_R2[:, 1:].T, cmap='rainbow', aspect='auto', origin='lower',
                 extent=[min(omega_range), max(omega_range), min(alp2_range), max(alp2_range)],
                 interpolation='bicubic')
ax2.set_xlabel('Rate for New Gossip ($\\omega$)', fontsize=14)
ax2.set_ylabel('Correction Rate of Gossip ($\\sigma$)', fontsize=14)
cbar2 = plt.colorbar(im2, ax=ax2)
cbar2.set_label('Attack Rate', fontsize=14)
cbar2.ax.tick_params(labelsize=14)
cbar2.ax.yaxis.set_major_formatter(FormatStrFormatter('%.3f'))

# Adding labels (A), (B) to each panel
ax1.text(-0.1, 1.05, '(A)', transform=ax1.transAxes, size=12, weight='bold')
ax2.text(-0.1, 1.05, '(B)', transform=ax2.transAxes, size=12, weight='bold')

# Set tick label sizes
plt.rc('xtick', labelsize=14)
plt.rc('ytick', labelsize=14)

# Save the combined figure
plt.tight_layout()
plt.savefig('/content/drive/My Drive/Information_Behavior_Disease_Networks/heat_map_results/WhatsApp_Twitter_C_to_A.pdf')
plt.show()
