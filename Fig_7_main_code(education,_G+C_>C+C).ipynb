 'N', 464: 'N', 10: 'N', 102: 'N', 259: 'N', 316: 'N', 414: 'N', 15: 'N', 53: 'N', 63: 'N', 118: 'N', 139: 'N', 180: 'N', 229: 'N', 299: 'N', 384: 'N', 31: 'N', 389: 'N', 468: 'N', 32: 'N', 106: 'N', 253: 'N', 364: 'N', 498: 'N', 5: 'N', 19: 'P', 94: 'N', 171: 'N', 228: 'N', 249: 'N', 334: 'N', 361: 'N', 418: 'N', 444: 'N', 495: 'N', 155: 'N', 320: 'P', 332: 'N', 409: 'N', 14: 'N', 140: 'N', 212: 'P', 226: 'N', 429: 'N', 6: 'N', 46: 'N', 97: 'N', 98: 'N', 164: 'N', 219: 'N', 237: 'N', 195: 'N', 397: 'N', 408: 'N', 443: 'N', 12: 'N', 197: 'N', 264: 'N', 265: 'N', 359: 'N', 442: 'N', 7: 'N', 119: 'N', 162: 'P', 257: 'N', 276: 'P', 341: 'N', 461: 'N', 35: 'N', 56: 'N', 352: 'N', 55: 'N', 345: 'N', 478: 'N', 8: 'N', 40: 'N', 38: 'N', 172: 'N', 183: 'N', 247: 'N', 324: 'N', 27: 'N', 79: 'N', 156: 'N', 200: 'N', 267: 'N', 291: 'N', 365: 'P', 39: 'N', 43: 'N', 192: 'N', 224: 'N', 24: 'N', 351: 'N', 434: 'N', 128: 'N', 145: 'P', 211: 'N', 283: 'N', 342: 'P', 375: 'N', 484: 'N', 42: 'N', 142: 'N', 236: 'N', 288: 'N', 449: 'N', 122: 'P', 261: 'P', 44: 'N', 201: 'N', 89: 'N', 121: 'N', 151: 'N', 405: 'N', 25: 'N', 78: 'P', 125: 'N', 143: 'P', 223: 'N', 403: 'N', 146: 'N', 157: 'N', 256: 'N', 339: 'N', 369: 'N', 402: 'N', 469: 'N', 149: 'N', 258: 'N', 317: 'N', 391: 'N', 447: 'N', 188: 'N', 312: 'N', 344: 'N', 413: 'N', 479: 'N', 240: 'N', 298: 'N', 377: 'N', 390: 'N', 476: 'N', 497: 'P', 33: 'N', 60: 'N', 251: 'N', 34: 'P', 166: 'N', 199: 'N', 218: 'N', 232: 'N', 279: 'N', 362: 'N', 467: 'N', 28: 'N', 189: 'N', 282: 'N', 315: 'N', 57: 'N', 101: 'N', 134: 'N', 310: 'N', 333: 'N', 435: 'N', 45: 'N', 103: 'N', 174: 'N', 206: 'N', 230: 'N', 301: 'N', 71: 'N', 92: 'N', 105: 'N', 133: 'N', 165: 'N', 181: 'N', 220: 'N', 336: 'P', 376: 'N', 366: 'N', 450: 'N', 485: 'N', 23: 'N', 190: 'P', 86: 'P', 307: 'N', 378: 'N', 458: 'N', 20: 'N', 204: 'N', 306: 'N', 453: 'P', 472: 'N', 274: 'N', 451: 'P', 322: 'N', 380: 'N', 433: 'N', 83: 'N', 202: 'N', 255: 'N', 277: 'N', 327: 'N', 387: 'N', 439: 'N', 349: 'N', 411: 'N', 440: 'N', 16: 'N', 138: 'N', 250: 'N', 492: 'N', 108: 'N', 159: 'N', 167: 'N', 213: 'N', 248: 'N', 290: 'N', 318: 'N', 487: 'N', 50: 'N', 72: 'N', 178: 'P
        # Determine if accept selected individual based on degree distribution
        q_deg_i = np.random.uniform()
        q_deg_c = np.random.uniform()
        q_deg_e = np.random.uniform()

        # Case 1: Rumor spreading
        if event < p1:
                response='F'
                while len(gossip)>0 and response =='F':
                  gossip_node = np.random.choice(gossip) #chose an infected node proportional to the degree
                  draw_rn = np.random.uniform()
                  if draw_rn < inw.degree(gossip_node)/kmax_i:
                     response='T'

                edges_containing_gossip = [edge for edge in inw.edges() if gossip_node in inw[edge]]
                if edges_containing_gossip:
                        rumor_hyper_edge = np.random.choice(edges_containing_gossip)
                        neighbors = inw[rumor_hyper_edge]
                        for neighbor in neighbors:
                            if info_states[neighbor] == "U":
                                count_gossip_neighbors = sum(1 for node in inw.neighbors(neighbor) if info_states[node] == "G")
                                if count_gossip_neighbors / len(inw.neighbors(neighbor)) >= ltre[neighbor]:
                                    info_states[neighbor] = "G"  # uninformed neighbor becomes gossip spreader
                                    gossip.append(neighbor)
                                    N_gossip += 1
                                    N_e_i += inw.degree(neighbor)
                                    #time_record.append(t)
                                    #gossip_count.append(N_gossip)
                                    #protected_count.append(N_protected)
                                    #prevalence_count.append(N_infected)
                                    #recovered_count.append(N_recovered)

        # Case 2: Rumor stifling (by meeting stifling neighbor threshold)
        elif event < p2:
                    response='F'
                    while len(gossip)>0 and response =='F':
                      stifler_node = np.random.choice(gossip) #chose an infected node proportional to the degree
                      draw_rn = np.random.uniform()
                      if draw_rn < inw.degree(stifler_node)/kmax_i:
                         response='T'

                    stifler_hyper_edge = np.random.choice(list(inw.edges()))
                    neighbors = inw[stifler_hyper_edge]
                    count_stifler_neighbors = sum(1 for node in inw.neighbors(stifler_node) if info_states[node] == "A")
                    if count_stifler_neighbors > 0:
                            info_states[stifler_node] = "A" #"C"
                            N_gossip -= 1
                            gossip.remove(stifler_node)
                            stifler.append(stifler_node) #corrected.append(stifler_node)
                            N_stifler += 1 #N_corrected += 1
                            N_e_i -= inw.degree(stifler_node)
                            #time_record.append(t)
                            #gossip_count.append(N_gossip)
                            #protected_count.append(N_protected)
                            #prevalence_count.append(N_infected)
                            #recovered_count.append(N_recovered)

        # Case 3: Rumor stifling (by meeting gossip neighbor threshold)
        elif event < p3:
                    response='F'
                    while len(gossip)>0 and response =='F':
                      stifler_node = np.random.choice(gossip) #chose an infected node proportional to the degree
                      draw_rn = np.random.uniform()
                      if draw_rn < inw.degree(stifler_node)/kmax_i:
                         response='T'

                    stifler_hyper_edge = np.random.choice(list(inw.edges()))
                    neighbors = inw[stifler_hyper_edge]
                    count_gossip_neighbors = sum(1 for node in inw.neighbors(stifler_node) if info_states[node] == "G")
                    if count_gossip_neighbors > 0:
                            info_states[stifler_node] = "A" #"C"
                            N_gossip -= 1
                            gossip.remove(stifler_node)
                            stifler.append(stifler_node) #corrected.append(stifler_node)
                            N_stifler += 1 #N_corrected += 1
                            N_e_i -= inw.degree(stifler_node)
                            #time_record.append(t)
                            #gossip_count.append(N_gossip)
                            #protected_count.append(N_protected)
                            #prevalence_count.append(N_infected)
                            #recovered_count.append(N_recovered)

        # Case 4: Disease propagation
        elif event < p4:
            # code based on the new pseudo code
            response='F'
            while len(infected)>0 and response =='F':  #draw node until degree distribution is reached and while the infected list is not empty
              infected_node = np.random.choice(infected) #choose an infected node proportional to the degree
              draw_rn = np.random.uniform()
              if draw_rn < enw.degree(infected_node)/kmax_e: # kmax_e is the global max degree
                 response='T'

            neighbors = list(enw.neighbors(infected_node)) #get the list of neighbors of the infected node
            target_node = np.random.choice(neighbors) #choose a neighbor at random
            # beta_NN > beta_PN > beta_NP > beta_PP
            if disease_states[target_node] == "S":
                if lprot[target_node] == "P" and lprot[infected_node] == "P":
                   beta_correct = beta_PP
                elif lprot[target_node] == "N" and lprot[infected_node] == "P":
                   beta_correct = beta_NP
                elif lprot[target_node] == "P" and lprot[infected_node] == "N":
                   beta_correct = beta_PN
                else:
                   beta_correct = beta_NN

                draw_rn = np.random.uniform()
                if draw_rn < beta_correct/beta_max:
                   disease_states[target_node] = "I"
                   infected.append(target_node)
                   N_infected += 1
                   N_e_e += enw.degree(target_node)
                   #time_record.append(t)
                   #gossip_count.append(N_gossip)
                   #protected_count.append(N_protected)
                   #prevalence_count.append(N_infected)
                   #recovered_count.append(N_recovered)

                   ## Start gossip after epidemic have started
                   if N_gossip == 0:
                      uninformed = [node for node, state in info_states.items() if state == "U" and node in inw.nodes()]
                      if len(uninformed) > 0:
                        rumor_node_0 = np.random.choice(uninformed)
                        info_states[rumor_node_0] = "G"
                        gossip.append(rumor_node_0)
                        N_gossip += 1
                        N_e_i += inw.degree(rumor_node_0)
                        #time_record.append(t)
                        #gossip_count.append(N_gossip)
                        #protected_count.append(N_protected)
                        #prevalence_count.append(N_infected)
                        #recovered_count.append(N_recovered)

        # Case 5: Disease recovery
        elif event < p5:
                  recovered_node = np.random.choice(infected)
                  disease_states[recovered_node] = "R"
                  infected.remove(recovered_node)
                  recovered.append(recovered_node)
                  N_infected -= 1
                  N_recovered += 1
                  N_e_e -= enw.degree(recovered_node)
                  time_record.append(t)
                  #gossip_count.append(N_gossip)
                  #protected_count.append(N_protected)
                  #prevalence_count.append(N_infected)
                  recovered_count.append(N_recovered)

        # Case 6: # Change to not adopting protection based on information layer
        # n_G is the total spreader neighbors on the information layer,
        # while k_info is the total neighbor count on the information layer
        elif event < p6:
            if len(protected) > 0:
              node_to_not_protect = np.random.choice(protected)
              n_G = sum(1 for node in filter(lambda x: info_states[x] == "G", inw.neighbors(node_to_not_protect)))
              k_info = len(list(inw.neighbors(node_to_not_protect)))
              frac_inf = N_infected/N
              b = 3
              if np.random.uniform() < (n_G / k_info) * (1-np.tanh(b*(frac_inf))):
                    lprot[node_to_not_protect] = "N"
                    protected.remove(node_to_not_protect)
                    not_protected.append(node_to_not_protect)
                    N_protected -= 1
                    #time_record.append(t)
                    #gossip_count.append(N_gossip)
                    #protected_count.append(N_protected)
                    #prevalence_count.append(N_infected)
                    #recovered_count.append(N_recovered)

        # Case 7: Change to adopting protection based on information layer
        elif event < p7:
            if len(not_protected) > 0:
                node_to_protect = np.random.choice(not_protected)
                n_G = sum(1 for node in filter(lambda x: info_states[x] == "G", inw.neighbors(node_to_protect)))
                k_info = len(list(inw.neighbors(node_to_protect)))
                frac_inf = N_infected/N
                b = 3
                if np.random.uniform() < (1 - n_G / k_info) * np.tanh(b*(frac_inf)):
                        lprot[node_to_protect] = "P"
                        not_protected.remove(node_to_protect)
                        protected.append(node_to_protect)
                        N_protected += 1
                        #time_record.append(t)
                        #gossip_count.append(N_gossip)
                        #protected_count.append(N_protected)
                        #prevalence_count.append(N_infected)
                        #recovered_count.append(N_recovered)


        # Case 8: # Change to not adopting protection based on neighborhood behavior in cognition layer
        # n_P is the total protected neighbors on the cognition layer,
        # while k_cog is the total neighbor count on the cognition layer
        elif event < p8:
            if len(protected) > 0:
                node_to_not_protect = np.random.choice(protected)
                n_P = sum(1 for node in filter(lambda x: lprot[x] == "P", cnw.neighbors(node_to_not_protect)))
                k_cog = len(list(cnw.neighbors(node_to_not_protect)))
                if np.random.uniform() < 1 - n_P / k_cog:
                        lprot[node_to_not_protect] = "N"
                        protected.remove(node_to_not_protect)
                        not_protected.append(node_to_not_protect)
                        N_protected -= 1
                        #time_record.append(t)
                        #gossip_count.append(N_gossip)
                        #protected_count.append(N_protected)
                        #prevalence_count.append(N_infected)
                        #recovered_count.append(N_recovered)


        # Case 9: # Change to adopting protection based on neighborhood behavior in cognition layer
        elif event < p9:
            if len(not_protected) > 0:
                node_to_protect = np.random.choice(not_protected)
                n_P = sum(1 for node in filter(lambda x: lprot[x] == "P", cnw.neighbors(node_to_protect)))
                k_cog = len(list(cnw.neighbors(node_to_protect)))
                if np.random.uniform() < n_P / k_cog:
                        lprot[node_to_protect] = "P"
                        not_protected.remove(node_to_protect)
                        protected.append(node_to_protect)
                        N_protected += 1
                        #time_record.append(t)
                        #gossip_count.append(N_gossip)
                        #protected_count.append(N_protected)
                        #prevalence_count.append(N_infected)
                        #recovered_count.append(N_recovered)

        # Case 10: Rumor interest renewal
        elif event < p10:
            if len(stifler) > 0:
                  stifler_node = np.random.choice(stifler)
                  info_states[stifler_node] = "U"
                  stifler.remove(stifler_node)
                  N_stifler -= 1

        # Case 11: Correction of rumor by education G+C->C+C
        elif event < p11:
                    response='F'
                    while len(gossip)>0 and response =='F':
                      target_node = np.random.choice(gossip) #chose an infected node proportional to the degree
                      draw_rn = np.random.uniform()
                      if draw_rn < inw.degree(target_node)/kmax_i:
                         response='T'

                    target_hyper_edge = np.random.choice(list(inw.edges()))
                    neighbors = inw[target_hyper_edge]
                    count_corrected_neighbors = sum(1 for node in inw.neighbors(target_node) if info_states[node] == "C")
                    if count_corrected_neighbors > 0:
                            info_states[target_node] = "C"
                            N_gossip -= 1
                            gossip.remove(target_node)
                            corrected.append(target_node)
                            N_corrected += 1
                            N_e_i -= inw.degree(target_node)

        # Case 12: Correction of rumor from outside G->C
        elif event < p12:
            if len(gossip)>0:
                correction_node = np.random.choice(gossip) #chose an infected node proportional to the degree
                info_states[correction_node] = "C"
                N_gossip -= 1
                gossip.remove(correction_node)
                corrected.append(correction_node)
                N_corrected += 1
                N_e_i -= inw.degree(correction_node)

        # Case 13: Corrected become stifler
        else:
          if len(corrected)>0:
                new_exposure_node = np.random.choice(corrected)
                info_states[new_exposure_node] = "A"
                N_corrected -= 1
                corrected.remove(new_exposure_node)
                N_stifler += 1
                stifler.append(new_exposure_node)

  return time_record, recovered_count

# %%
# No Control single run
lam = 1/3
alp = 1/3
#omega = 1/5
#sigma = 1/10
phi = 1/5
zeta_1 = 0.2 #go to not protect by information
zeta_2 = 0.2 #go to protect by information
zeta_3 = 0 #go to not protect by neighborhood behavior
zeta_4 = 0 #go to protect by neighborhood behavior
mu = 0.2
R0 = 4.0 #(assume a COVID19-like disease for the reproduction number) #2.0 # reproduction number
beta_NN = R0 * mu / division_factor
beta_PN = beta_NN * 0.2
beta_NP = beta_NN * 0.1
beta_PP = beta_NN * 0.0
n_sample = 1

#time_record, recovered_count = ICE_model_record_layer(inw, ldeg_i, ltre, cnw, ldeg_c, lprot, enw, ldeg_e, lam, alp, omega, sigma, zeta_1, zeta_2, zeta_3, zeta_4, beta_PP, beta_NP, beta_PN, beta_NN, mu, n_sample)

#plt.plot(time_record, recovered_count)
#plt.xlabel(r'Time', fontsize=14)
#plt.ylabel(r'Number of recovered', fontsize=14)

#recovered_count[-1]

# %%
n_iterations = 100
# Define the range for omega and sigma
#omega_range = sigma_range = [i * 0.1 for i in range(5)]

omega_range = np.round([i * 0.20 for i in range(11)], 2)
sigma_range = np.round([i * 0.05 for i in range(11)], 2)

# Initialize data for heatmap
heatmap_data = np.zeros((len(omega_range), len(sigma_range)))

# Iterate over omega and sigma combinations
for i, omega in enumerate(omega_range):
    for j, sigma in enumerate(sigma_range):
        recovered_counts = []

        for _ in range(n_iterations):
            time_record, recovered_count = ICE_model_record_layer_education(inw, ldeg_i, ltre, cnw, ldeg_c, lprot, enw, ldeg_e, lam, alp, omega, sigma, phi, zeta_1, zeta_2, zeta_3, zeta_4, beta_PP, beta_NP, beta_PN, beta_NN, mu, n_sample)

            final_recovered_count = recovered_count[-1]
            recovered_counts.append(final_recovered_count)

        attack_rate = np.mean(recovered_counts)/500
        heatmap_data[i, j] = attack_rate

        print(f"Omega: {omega}, Sigma: {sigma}, Attack Rate: {attack_rate}")

# Store data
import csv
file_path = '/content/drive/My Drive/Information_Behavior_Disease_Networks/heat_map_results/Heatmap_education.csv'
with open(file_path, 'w', newline='') as file:
    writer = csv.writer(file)

    # Write the header row with omega values
    header = ['Omega \\ Sigma'] + sigma_range.tolist()
    writer.writerow(header)

    # Write the data rows
    for i, omega in enumerate(omega_range):
        row = [omega] + heatmap_data[i].tolist()
        writer.writerow(row)

print(f"Data has been written.")
# Out:
# Omega: 0.0, Sigma: 0.0, Attack Rate: 0.1149
# Omega: 0.0, Sigma: 0.05, Attack Rate: 0.11031999999999999
# Omega: 0.0, Sigma: 0.1, Attack Rate: 0.11796
# Omega: 0.0, Sigma: 0.15, Attack Rate: 0.11362
# Omega: 0.0, Sigma: 0.2, Attack Rate: 0.11608
# Omega: 0.0, Sigma: 0.25, Attack Rate: 0.12294
# Omega: 0.0, Sigma: 0.3, Attack Rate: 0.11134000000000001
# Omega: 0.0, Sigma: 0.35, Attack Rate: 0.10787999999999999
# Omega: 0.0, Sigma: 0.4, Attack Rate: 0.10851999999999999
# Omega: 0.0, Sigma: 0.45, Attack Rate: 0.1151
# Omega: 0.0, Sigma: 0.5, Attack Rate: 0.10934
# Omega: 0.2, Sigma: 0.0, Attack Rate: 0.12108
# Omega: 0.2, Sigma: 0.05, Attack Rate: 0.1141
# Omega: 0.2, Sigma: 0.1, Attack Rate: 0.11206
# Omega: 0.2, Sigma: 0.15, Attack Rate: 0.11504
# Omega: 0.2, Sigma: 0.2, Attack Rate: 0.11431999999999999
# Omega: 0.2, Sigma: 0.25, Attack Rate: 0.10968000000000001
# Omega: 0.2, Sigma: 0.3, Attack Rate: 0.11295999999999999
# Omega: 0.2, Sigma: 0.35, Attack Rate: 0.10936
# Omega: 0.2, Sigma: 0.4, Attack Rate: 0.11295999999999999
# Omega: 0.2, Sigma: 0.45, Attack Rate: 0.11123999999999999
# Omega: 0.2, Sigma: 0.5, Attack Rate: 0.11278
# Omega: 0.4, Sigma: 0.0, Attack Rate: 0.1215
# Omega: 0.4, Sigma: 0.05, Attack Rate: 0.11802
# Omega: 0.4, Sigma: 0.1, Attack Rate: 0.10966
# Omega: 0.4, Sigma: 0.15, Attack Rate: 0.1108
# Omega: 0.4, Sigma: 0.2, Attack Rate: 0.10916
# Omega: 0.4, Sigma: 0.25, Attack Rate: 0.11516
# Omega: 0.4, Sigma: 0.3, Attack Rate: 0.10834
# Omega: 0.4, Sigma: 0.35, Attack Rate: 0.11674
# Omega: 0.4, Sigma: 0.4, Attack Rate: 0.10834
# Omega: 0.4, Sigma: 0.45, Attack Rate: 0.11436
# Omega: 0.4, Sigma: 0.5, Attack Rate: 0.10892
# Omega: 0.6, Sigma: 0.0, Attack Rate: 0.12490000000000001
# Omega: 0.6, Sigma: 0.05, Attack Rate: 0.11871999999999999
# Omega: 0.6, Sigma: 0.1, Attack Rate: 0.11294
# Omega: 0.6, Sigma: 0.15, Attack Rate: 0.11198000000000001
# Omega: 0.6, Sigma: 0.2, Attack Rate: 0.11696
# Omega: 0.6, Sigma: 0.25, Attack Rate: 0.11131999999999999
# Omega: 0.6, Sigma: 0.3, Attack Rate: 0.10926000000000001
# Omega: 0.6, Sigma: 0.35, Attack Rate: 0.1123
# Omega: 0.6, Sigma: 0.4, Attack Rate: 0.11495999999999999
# Omega: 0.6, Sigma: 0.45, Attack Rate: 0.10338
# Omega: 0.6, Sigma: 0.5, Attack Rate: 0.11454
# Omega: 0.8, Sigma: 0.0, Attack Rate: 0.13058
# Omega: 0.8, Sigma: 0.05, Attack Rate: 0.12776
# Omega: 0.8, Sigma: 0.1, Attack Rate: 0.1153
# Omega: 0.8, Sigma: 0.15, Attack Rate: 0.12186
# Omega: 0.8, Sigma: 0.2, Attack Rate: 0.11322
# Omega: 0.8, Sigma: 0.25, Attack Rate: 0.11094
# Omega: 0.8, Sigma: 0.3, Attack Rate: 0.11238
# Omega: 0.8, Sigma: 0.35, Attack Rate: 0.11288
# Omega: 0.8, Sigma: 0.4, Attack Rate: 0.10851999999999999
# Omega: 0.8, Sigma: 0.45, Attack Rate: 0.11642
# Omega: 0.8, Sigma: 0.5, Attack Rate: 0.10840000000000001
# Omega: 1.0, Sigma: 0.0, Attack Rate: 0.12838
# Omega: 1.0, Sigma: 0.05, Attack Rate: 0.13088
# Omega: 1.0, Sigma: 0.1, Attack Rate: 0.11832
# Omega: 1.0, Sigma: 0.15, Attack Rate: 0.11592
# Omega: 1.0, Sigma: 0.2, Attack Rate: 0.10796
# Omega: 1.0, Sigma: 0.25, Attack Rate: 0.11804
# Omega: 1.0, Sigma: 0.3, Attack Rate: 0.11788
# Omega: 1.0, Sigma: 0.35, Attack Rate: 0.11388
# Omega: 1.0, Sigma: 0.4, Attack Rate: 0.11284000000000001
# Omega: 1.0, Sigma: 0.45, Attack Rate: 0.1105
# Omega: 1.0, Sigma: 0.5, Attack Rate: 0.11016
# Omega: 1.2, Sigma: 0.0, Attack Rate: 0.13008
# Omega: 1.2, Sigma: 0.05, Attack Rate: 0.13082
# Omega: 1.2, Sigma: 0.1, Attack Rate: 0.11718
# Omega: 1.2, Sigma: 0.15, Attack Rate: 0.11356000000000001
# Omega: 1.2, Sigma: 0.2, Attack Rate: 0.11214
# Omega: 1.2, Sigma: 0.25, Attack Rate: 0.1182
# Omega: 1.2, Sigma: 0.3, Attack Rate: 0.11884
# Omega: 1.2, Sigma: 0.35, Attack Rate: 0.11036
# Omega: 1.2, Sigma: 0.4, Attack Rate: 0.11270000000000001
# Omega: 1.2, Sigma: 0.45, Attack Rate: 0.1148
# Omega: 1.2, Sigma: 0.5, Attack Rate: 0.11116
# Omega: 1.4, Sigma: 0.0, Attack Rate: 0.13813999999999999
# Omega: 1.4, Sigma: 0.05, Attack Rate: 0.1419
# Omega: 1.4, Sigma: 0.1, Attack Rate: 0.12812
# Omega: 1.4, Sigma: 0.15, Attack Rate: 0.121
# Omega: 1.4, Sigma: 0.2, Attack Rate: 0.11394
# Omega: 1.4, Sigma: 0.25, Attack Rate: 0.11464
# Omega: 1.4, Sigma: 0.3, Attack Rate: 0.10887999999999999
# Omega: 1.4, Sigma: 0.35, Attack Rate: 0.10601999999999999
# Omega: 1.4, Sigma: 0.4, Attack Rate: 0.11092
# Omega: 1.4, Sigma: 0.45, Attack Rate: 0.11159999999999999
# Omega: 1.4, Sigma: 0.5, Attack Rate: 0.11358
# Omega: 1.6, Sigma: 0.0, Attack Rate: 0.14242
# Omega: 1.6, Sigma: 0.05, Attack Rate: 0.12426000000000001
# Omega: 1.6, Sigma: 0.1, Attack Rate: 0.12236
# Omega: 1.6, Sigma: 0.15, Attack Rate: 0.12196
# Omega: 1.6, Sigma: 0.2, Attack Rate: 0.11924
# Omega: 1.6, Sigma: 0.25, Attack Rate: 0.11871999999999999
# Omega: 1.6, Sigma: 0.3, Attack Rate: 0.10665999999999999
# Omega: 1.6, Sigma: 0.35, Attack Rate: 0.11942
# Omega: 1.6, Sigma: 0.4, Attack Rate: 0.11223999999999999
# Omega: 1.6, Sigma: 0.45, Attack Rate: 0.11159999999999999
# Omega: 1.6, Sigma: 0.5, Attack Rate: 0.11128
# Omega: 1.8, Sigma: 0.0, Attack Rate: 0.14748
# Omega: 1.8, Sigma: 0.05, Attack Rate: 0.13972
# Omega: 1.8, Sigma: 0.1, Attack Rate: 0.13038
# Omega: 1.8, Sigma: 0.15, Attack Rate: 0.11522
# Omega: 1.8, Sigma: 0.2, Attack Rate: 0.12106
# Omega: 1.8, Sigma: 0.25, Attack Rate: 0.11136
# Omega: 1.8, Sigma: 0.3, Attack Rate: 0.11184000000000001
# Omega: 1.8, Sigma: 0.35, Attack Rate: 0.12246
# Omega: 1.8, Sigma: 0.4, Attack Rate: 0.11624
# Omega: 1.8, Sigma: 0.45, Attack Rate: 0.11572
# Omega: 1.8, Sigma: 0.5, Attack Rate: 0.11322
# Omega: 2.0, Sigma: 0.0, Attack Rate: 0.14646
# Omega: 2.0, Sigma: 0.05, Attack Rate: 0.13604
# Omega: 2.0, Sigma: 0.1, Attack Rate: 0.12788

# %%
df = pd.read_csv('/content/drive/My Drive/Information_Behavior_Disease_Networks/heat_map_results/Heatmap_education.csv', header = 0)

omega_range = df.columns[1:].astype(float)
sigma_range = df.iloc[:, 0].astype(float)

sparse_yticks = np.arange(0, len(omega_range), 2)
sparse_xticks = np.arange(0, len(sigma_range), 2)

sparse_ytick_labels = omega_range[::2]
sparse_xtick_labels = sigma_range[::2]

heatmap_data = df.iloc[:, 1:].values

plt.figure(figsize=(8, 6))
plt.xlabel('Rate for New Gossip ($\\omega$)', fontsize=16)
plt.ylabel('Correction Rate of Gossip ($\\sigma$)', fontsize=16)
plt.imshow(heatmap_data.T, cmap='jet', interpolation='bicubic')
cbar = plt.colorbar()
cbar.set_label('Attack Rate', fontsize=16)
cbar.ax.tick_params(labelsize=14)
#cbar.ax.yaxis.set_major_formatter(FormatStrFormatter('%.3f'))
plt.xticks(sparse_xticks, sparse_xtick_labels, fontsize=14)
plt.yticks(sparse_yticks, sparse_ytick_labels, fontsize=14)
plt.gca().invert_yaxis()
plt.tight_layout()

plt.savefig('/content/drive/My Drive/Information_Behavior_Disease_Networks/heat_map_results/Heatmap_education.pdf')
plt.show()

# %%
from matplotlib.ticker import FormatStrFormatter
# Load dataset
df1 = pd.read_csv('/content/drive/My Drive/Information_Behavior_Disease_Networks/heat_map_results/Heatmap_Twitter_C_to_A.csv', header = 0)
results_rho_R1 = df1.to_numpy()

df2 = pd.read_csv('/content/drive/My Drive/Information_Behavior_Disease_Networks/heat_map_results/Heatmap_education.csv', header = 0)
results_rho_R2 = df2.to_numpy()

omega_range = np.round([i * 0.20 for i in range(11)], 2)
alp2_range = np.round([i * 0.05 for i in range(11)], 2)

# Create a figure with two subplots
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(12, 5))

im1 = ax1.imshow(results_rho_R1[:, 1:].T, cmap='jet', aspect='auto', origin='lower',
                 extent=[min(omega_range), max(omega_range), min(alp2_range), max(alp2_range)],
                 interpolation='bicubic',vmin=0.100,vmax=0.155)
ax1.set_xlabel('Rate for New Gossip ($\\omega$)', fontsize=14)
ax1.set_ylabel('Correction Rate of Gossip ($\\sigma$)', fontsize=14)
cbar1 = plt.colorbar(im1, ax=ax1)
cbar1.set_label('Attack Rate', fontsize=14)
cbar1.ax.tick_params(labelsize=14)
cbar1.ax.yaxis.set_major_formatter(FormatStrFormatter('%.2f'))

im2 = ax2.imshow(results_rho_R2[:, 1:].T, cmap='jet', aspect='auto', origin='lower',
                 extent=[min(omega_range), max(omega_range), min(alp2_range), max(alp2_range)],
                 interpolation='bicubic',vmin=0.100,vmax=0.155)
ax2.set_xlabel('Rate for New Gossip ($\\omega$)', fontsize=14)
ax2.set_ylabel('Correction Rate of Gossip ($\\sigma$)', fontsize=14)
cbar2 = plt.colorbar(im2, ax=ax2)
cbar2.set_label('Attack Rate', fontsize=14)
cbar2.ax.tick_params(labelsize=14)
cbar2.ax.yaxis.set_major_formatter(FormatStrFormatter('%.2f'))

# Adding labels (A), (B) to each panel
ax1.text(-0.1, 1.05, '(A)', transform=ax1.transAxes, size=12, weight='bold')
ax2.text(-0.1, 1.05, '(B)', transform=ax2.transAxes, size=12, weight='bold')

# Set tick label sizes
plt.rc('xtick', labelsize=14)
plt.rc('ytick', labelsize=14)

# Save the combined figure
plt.tight_layout()
plt.savefig('/content/drive/My Drive/Information_Behavior_Disease_Networks/heat_map_results/suspend_and_education.pdf')
plt.show()
