# %% [markdown]
# <a href="https://colab.research.google.com/github/Nancy-Shi/ICE_Final/blob/main/Warning_peers.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## 3-Layer Model with Informtion, Behavior, Disease

# %%
#!pip install hypernetx

# %%
import warnings
warnings.filterwarnings("ignore", category=DeprecationWarning)

# %%
import hypernetx as hnx

# %%
import numpy as np
import matplotlib.pyplot as plt
import networkx as nx
import random
import math as math
from math import log
import seaborn as sns
import pandas as pd
import matplotlib.ticker as ticker

# %% [markdown]
# ## Part 1: Hypergraph Generation
# The following steps generate a hyper graph using the XGI/HyperNetX python package,  following power-law degree distribution for predifined number of nodes n, number of hyperedges num_hyper_edges, degree exponent gamma, using a configuration model with data stored in a dictionary.

# %%
# Step 1: Generate Degree Sequence
def generate_degree_sequence(n, gamma, kmin):
    # Generate a random set from the power law distribution
    u = np.random.uniform(size=n)
    degrees = np.ceil((1.0 - u) ** (-1.0 / (gamma - 1.0)))

    kmax = int(np.sqrt(n))
    #kmax = int(((gamma-1)/(gamma-2) * n )** (1/gamma))  # max degree
    degrees = degrees[(degrees >= kmin) & (degrees <= kmax)].astype(int)
    if len(degrees) >= n:
        degrees = degrees[:n]
    else:
        degrees = np.concatenate((degrees, np.full(n - len(degrees), kmin)))

    return degrees.tolist()

# Step 2: Generate Hyper Edge Size Sequence
def generate_hyper_edge_sizes(degrees, num_hyper_edges):
    total_degrees = sum(degrees)
    hyper_edge_sizes = []

    avg_size = total_degrees // num_hyper_edges
    remainder = total_degrees % num_hyper_edges

    min_size = 2  # Lower bound of the range
    max_size = int(np.sqrt(total_degrees))  # Upper bound of the range

    for _ in range(num_hyper_edges):
        size = random.randint(min_size, max_size)
        hyper_edge_sizes.append(size)

    return hyper_edge_sizes


# Step 3: Create Copies of Nodes
def create_node_copies(degrees):
    node_copies = []
    for i, degree in enumerate(degrees):
        for _ in range(degree):
            node_copies.append(i)
    return node_copies

# Step 4: Create Copies of Hyper Edges
def create_hyper_edge_copies(hyper_edge_sizes):
    hyper_edge_copies = []
    for i, size in enumerate(hyper_edge_sizes):
        for _ in range(size):
            hyper_edge_copies.append(i)
    return hyper_edge_copies

# Step 5: Randomly Pair Copies without Repeated Pairs
def randomly_pair_copies(node_copies, hyper_edge_copies):
    pairs = []
    paired_hyper_edges = {}

    for node_copy in node_copies:
        available_hyper_edges = [h for h in hyper_edge_copies if (h, node_copy) not in paired_hyper_edges]

        if not available_hyper_edges:
            paired_hyper_edges = {}
            available_hyper_edges = [h for h in hyper_edge_copies if (h, node_copy) not in paired_hyper_edges]

        chosen_hyper_edge = random.choice(available_hyper_edges)
        pairs.append((node_copy, chosen_hyper_edge))

        paired_hyper_edges[(chosen_hyper_edge, node_copy)] = True
        hyper_edge_copies.remove(chosen_hyper_edge)

    return pairs

# Step 6: Convert Bipartite Graph to A Hypergraph Dictionary
def convert_to_hypergraph(pairs):
    hypergraph = {}
    for pair in pairs:
        node, hyper_edge = pair
        if hyper_edge in hypergraph:
            hypergraph[hyper_edge].append(node)
        else:
            hypergraph[hyper_edge] = [node]
    return hypergraph

# %%
def build_hypergraph(n, gamma, kmin, num_hyper_edges):
    # Step 1: Generate Degree Sequence
    degrees = generate_degree_sequence(n, gamma, kmin)
    print("Degree Sequence: ", degrees)

    # Step 2: Generate Hyper Edge Size Sequence
    hyper_edge_sizes = generate_hyper_edge_sizes(degrees, num_hyper_edges)
    print("Hyper Edge Sizes: ", hyper_edge_sizes)

    # Step 3: Create Copies of Nodes
    node_copies = create_node_copies(degrees)

    # Step 4: Create Copies of Hyper Edges
    hyper_edge_copies = create_hyper_edge_copies(hyper_edge_sizes)

    # Step 5: Randomly Pair Copies
    pairs = randomly_pair_copies(node_copies, hyper_edge_copies)

    # Step 6: Convert Bipartite Graph to Hypergraph
    hyperedge_dict = convert_to_hypergraph(pairs)

    # Print the resulting hypergraph
    print("Hypergraph Dictionary: ", hyperedge_dict)

    return degrees, hyperedge_dict

# %%
# Test 2
n2 = 500  # Number of nodes
gamma2 = 2.5  # Power-law exponent
kmin2 = 3  # Minimum degree
num_hyper_edges2 = 300  # Desired number of hyper edges

degrees2, hyperedge_dict2 = build_hypergraph(n2, gamma2, kmin2, num_hyper_edges2)
H2 = hnx.Hypergraph(hyperedge_dict2)
# Out:
# Degree Sequence:  [3, 4, 3, 3, 3, 3, 6, 3, 3, 6, 3, 5, 4, 3, 9, 3, 3, 4, 3, 4, 5, 3, 5, 14, 3, 4, 6, 3, 3, 14, 3, 6, 4, 3, 3, 6, 3, 3, 3, 3, 4, 3, 5, 3, 5, 5, 4, 3, 4, 4, 4, 13, 6, 3, 4, 3, 4, 3, 3, 7, 3, 3, 3, 3, 3, 12, 4, 3, 4, 3, 11, 4, 6, 7, 3, 5, 3, 5, 3, 10, 3, 10, 3, 3, 3, 3, 4, 16, 4, 11, 6, 10, 3, 3, 13, 4, 4, 4, 5, 3, 3, 3, 3, 3, 6, 4, 4, 5, 3, 3, 9, 10, 3, 8, 3, 3, 3, 4, 3, 3, 3, 7, 22, 4, 6, 3, 3, 5, 3, 3, 3, 5, 3, 17, 3, 3, 4, 4, 11, 3, 7, 4, 3, 5, 7, 3, 3, 3, 6, 3, 4, 4, 6, 3, 3, 3, 3, 5, 3, 4, 3, 3, 4, 7, 6, 5, 4, 4, 6, 12, 5, 4, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3]
# Hyper Edge Sizes:  [2, 26, 23, 36, 38, 7, 34, 36, 33, 16, 31, 27, 37, 26, 40, 41, 15, 31, 39, 15, 10, 24, 31, 39, 30, 13, 16, 25, 34, 11, 11, 24, 5, 24, 7, 37, 36, 7, 23, 21, 3, 9, 3, 31, 41, 22, 26, 35, 31, 6, 39, 36, 37, 24, 15, 12, 34, 33, 2, 13, 8, 28, 4, 10, 33, 20, 21, 12, 24, 4, 32, 2, 37, 23, 40, 24, 5, 15, 35, 9, 33, 41, 25, 17, 34, 6, 2, 8, 30, 5, 4, 12, 6, 2, 13, 35, 2, 41, 34, 36, 2, 2, 31, 3, 19, 3, 30, 19, 4, 22, 11, 33, 9, 7, 21, 26, 15, 15, 10, 26, 41, 38, 37, 12, 18, 28, 11, 15, 9, 12, 24, 11, 35, 8, 28, 14, 24, 24, 29, 6, 21, 2, 8, 34, 41, 5, 40, 9, 29, 33, 6, 11, 11, 10, 34, 21, 20, 7,
    for node in nodes:
        if node in nodes_to_protect:
            protection_status[node] = "P"  # Protected node
        else:
            protection_status[node] = "N"  # Non-protected node

    return protection_status

# %%
# Test:
fraction_protected = 0.1
protection_status_dict = assign_protection(H2, fraction_protected)
print(protection_status_dict)
# Out:
# {0: 'N', 26: 'N', 34: 'P', 50: 'N', 96: 'P', 127: 'N', 211: 'N', 257: 'N', 266: 'N', 16: 'N', 85: 'N', 101: 'N', 122: 'N', 267: 'N', 312: 'N', 331: 'N', 380: 'N', 15: 'N', 70: 'N', 125: 'N', 169: 'N', 198: 'N', 236: 'N', 268: 'P', 327: 'N', 334: 'P', 348: 'N', 355: 'N', 488: 'N', 1: 'N', 31: 'N', 43: 'N', 104: 'N', 111: 'N', 235: 'P', 341: 'P', 388: 'N', 404: 'N', 115: 'N', 383: 'N', 18: 'N', 29: 'N', 116: 'N', 123: 'N', 138: 'P', 243: 'N', 269: 'N', 470: 'N', 130: 'N', 294: 'N', 350: 'N', 403: 'N', 413: 'N', 491: 'N', 2: 'N', 8: 'N', 14: 'N', 56: 'N', 134: 'N', 178: 'N', 191: 'N', 282: 'N', 386: 'N', 412: 'N', 423: 'N', 498: 'N', 65: 'N', 87: 'N', 113: 'P', 133: 'N', 409: 'N', 42: 'N', 88: 'P', 92: 'N', 152: 'P', 164: 'N', 241: 'N', 322: 'N', 420: 'N', 3: 'P', 23: 'N', 66: 'N', 68: 'N', 74: 'N', 95: 'N', 150: 'N', 349: 'N', 432: 'N', 499: 'N', 12: 'N', 79: 'N', 137: 'N', 376: 'N', 4: 'N', 37: 'N', 165: 'N', 199: 'N', 279: 'N', 384: 'N', 484: 'N', 490: 'N', 44: 'N', 49: 'N', 51: 'N', 76: 'N', 97: 'N', 128: 'N', 148: 'N', 159: 'N', 271: 'N', 314: 'N', 371: 'N', 425: 'N', 429: 'N', 474: 'N', 99: 'N', 118: 'N', 140: 'N', 313: 'N', 343: 'N', 411: 'N', 416: 'N', 431: 'N', 5: 'N', 58: 'N', 62: 'N', 356: 'N', 414: 'N', 434: 'N', 457: 'N', 64: 'N', 89: 'N', 440: 'N', 75: 'N', 94: 'N', 452: 'N', 6: 'N', 13: 'N', 124: 'N', 217: 'N', 326: 'N', 424: 'P', 168: 'N', 325: 'N', 439: 'P', 9: 'N', 19: 'N', 144: 'N', 160: 'N', 195: 'N', 203: 'P', 489: 'N', 126: 'N', 363: 'N', 379: 'N', 382: 'N', 421: 'N', 45: 'N', 110: 'N', 141: 'N', 163: 'N', 188: 'P', 378: 'N', 407: 'P', 436: 'N', 487: 'N', 131: 'P', 213: 'N', 7: 'N', 451: 'N', 275: 'N', 284: 'N', 293: 'N', 351: 'N', 22: 'N', 54: 'N', 190: 'N', 231: 'N', 72: 'N', 185: 'N', 249: 'N', 360: 'N', 10: 'N', 47: 'N', 73: 'N', 103: 'P', 112: 'P', 216: 'P', 52: 'N', 298: 'N', 370: 'N', 433: 'N', 427: 'N', 445: 'N', 136: 'N', 182: 'N', 222: 'P', 281: 'N', 340: 'N', 368: 'N', 48: 'N', 55: 'N', 71: 'N', 170: 'N', 449: 'N', 480: 'N', 481: 'N', 495: 'N', 155: 'N', 186: 'N', 201: 'N', 207: 'N', 226: 'N', 426: 'N', 117: 'N', 206: 'N', 210: 'N', 253: 'N', 254: 'N', 278: 'N', 435: 'N', 81: 'N', 105: 'N', 172: 'N', 193: 'N', 244: 'N', 303: 'N', 324: 'N', 473: 'P', 11: 'P', 46: 'N', 369: 'N', 393: 'N', 446: 'N', 20: 'N', 35: 'N', 287: 'N', 344: 'N', 114: 'N', 151: 'N', 270: 'N', 345: 'N', 366: 'N', 248: 'N', 255: 'N', 256: 'P', 336: 'N', 139: 'N', 175: 'N', 215: 'N', 229: 'N', 467: 'N', 36: 'N', 119: 'N', 157: 'N', 230: 'N', 359: 'N', 59: 'N', 184: 'N', 276: 'N', 454: 'N', 353: 'N', 24: 'N', 239: 'N', 28: 'N', 69: 'N', 223: 'N', 228: 'N', 283: 'N', 319: 'N', 352: 'N', 493: 'N', 233: 'N', 261: 'N', 335: 'N', 477: 'N', 107: 'N', 132: 'N', 187: 'N', 297: 'P', 121: 'N', 146: 'N', 329: 'N', 377: 'N', 479: 'P', 246: 'N', 400: 'N', 483: 'N', 38: 'N', 167: 'N', 264: 'N', 277: 'N', 392: 'N', 396: 'N', 486: 'N', 27: 'N', 41: 'N', 106: 'P', 153: 'P', 197: 'N', 288: 'N', 453: 'N', 468: 'N', 482: 'N', 17: 'N', 337: 'N', 61: 'N', 496: 'N', 77: 'N', 330: 'N', 174: 'P', 247: 'P', 461: 'N', 332: 'N', 39: 'N', 142: 'N', 143: 'N', 381: 'N', 202: 'N', 309: 'N', 333: 'N', 292: 'N', 307: 'N', 385: 'N', 469: 'N', 129: 'N', 291: 'P', 375: 'N', 135: 'N', 158: 'N', 200: 'P', 408: 'N', 234: 'N', 389: 'P', 30: 'N', 32: 'N', 21: 'N', 305: 'N', 306: 'N', 361: 'N', 401: 'N', 465: 'N', 53: 'N', 459: 'N', 91: 'N', 245: 'N', 260: 'P', 120: 'N', 176: 'N', 220: 'N', 485: 'N', 321: 'N', 147: 'N', 171: 'N', 225: 'N', 302: 'N', 402: 'N', 478: 'N', 67: 'N', 80: 'N', 189: 'N', 224: 'P', 286: 'N', 362: 'N', 98: 'N', 367: 'N', 399: 'P', 415: 'N', 240: 'N', 259: 'N', 295: 'N', 317: 'N', 318: 'N', 177: 'N', 183: 'N', 347: 'N', 154: 'N', 219: 'N', 40: 'N', 323: 'N', 374: 'N', 196: 'N', 273: 'N', 296: 'P', 372: 'N', 410: 'N', 338: 'N', 100: 'N', 448: 'N', 25: 'P', 204: 'P', 212: 'N', 232: 'N', 437: 'N', 442: 'P', 358: 'N', 458: 'N', 471: 'N', 476: 'N', 342: 'N', 354: 'N', 390: 'N', 289: 'N', 84: 'N', 102: 'N', 455: 'N', 33: 'N', 192: 'N', 60: 'N', 339: 'N', 1 ...

# %% [markdown]
# ## Part 3: Assign Threshold
# The following steps assigns a threshold value to each node in the network. The threshold follows a uniform or normal distribution with predefined mean (mu) and standard deviation (sigma).

: 0.1070386555232283, 44: 0.005243459171807588, 49: 0.0919346951842081, 51: 0.10601282899761283, 76: 0.12248060158745715, 97: 0.06249050406767423, 128: 0.12608001651791143, 148: 0.15398699258528092, 159: 0.11432627503074927, 271: 0.12728835806073643, 314: 0.03651941919185295, 371: 0.10217302826339963, 425: 0.18224545420747673, 429: 0.05253145441944597, 474: 0.12581837045989633, 99: 0.1642494892997175, 118: 0.09428574225565249, 140: 0.027778717817641144, 313: 0.04974955761250788, 343: 0.051277194361177475, 411: 0.12742049837869415, 416: 0.15470335880824596, 431: 0.2037938360776391, 5: 0.13684287044406396, 58: 0.1736780450216145, 62: 0.1338072051547675, 356: 0.18090416608681215, 414: 0.037550827835508886, 434: 0.1401949818917956, 457: 0.06393752479486506, 64: 0.07981106599217111, 89: 0.15269588905200387, 440: 0.11945758670126115, 75: 0.09770727781193804, 94: 0.02324586682532026, 452: 0.006705807881772538, 6: 0.10235007026649867, 13: 0.11128610721413217, 124: 0.13352580942340989, 217: 0.0603019890830504, 326: 0.05082310048211402, 424: 0.07528452938416218, 168: 0.21594213875636792, 325: 0.08079392176327825, 439: 0.11294266412939413, 9: 0.16866081188400428, 19: 0.11789728446406317, 144: 0.10361002000564447, 160: 0.05557996978307115, 195: 0.06794344044432801, 203: 0.08034886810879248, 489: 0.23809821801315226, 126: 0.11551450416117391, 363: 0.129486115585067, 379: 0.12654966432217604, 382:  ...

# %% [markdown]
# # Part 4: The ICE Model (The Information Cognition Epidemics Model)
# ## Information Layer
# The misinformation spread occurs on a hyperedge network involving group spreading. The three stages are U(unaware), G(gossip/spreader), and C(stifler/corrected).
#
# ## Cognition Layer
# In the cognitive behavioral layer, P is protected, and N is not protected. The rate of transition from state P to N, p, depends on the information layer. The rate from NP to P is 1-p. The transition rate of a node is also affected by the number of active spreader/stiflers. The bigger number of active neighbors, the faster the rate. Another way behavior may change is based on the fraction of protected neighbors.
#
# ## Epidemics Layer
# In the epidemics layer, the possible disease states are S(susceptible), I(infected), and R(recovered). The illness spreading is pairwise. The disease propagation rate depends on the fraction of protected individuals $\rho_P$.

# %%
n = 500  # Number of nodes

# Information Layer
gamma_i = 2.5  # Power-law exponent
kmin_i = 3  # Minimum degree
num_hyper_edges_i = 450  # Desired number of hyper edges
ldeg_i, hyperedge_dict_i = build_hypergraph(n, gamma_i, kmin_i, num_hyper_edges_i)
inw = hnx.Hypergraph(hyperedge_dict_i)
ltre = assign_thresholds(inw, 0.10, 0.05)
print("Acceptance Threshold Sequence: ", ltre)
# Out:
# Degree Sequence:  [5, 3, 3, 3, 4, 5, 3, 4, 3, 4, 3, 7, 3, 4, 3, 3, 6, 3, 3, 3, 3, 6, 3, 3, 3, 6, 4, 7, 3, 3, 3, 4, 3, 3, 6, 3, 3, 3, 3, 6, 4, 3, 3, 3, 6, 3, 3, 5, 10, 3, 20, 4, 4, 14, 6, 3, 7, 10, 3, 3, 3, 4, 6, 4, 5, 3, 3, 3, 5, 3, 4, 3, 3, 5, 3, 13, 4, 11, 3, 3, 7, 3, 3,
print("Behavior Degree Sequence: ", ldeg_c)
cnw = nx.configuration_model(ldeg_c)
frac_prot = 0.05
lprot = assign_protection(cnw, frac_prot)
# Out:
# Behavior Degree Sequence:  [4, 3, 4, 3, 3, 3, 3, 3, 6, 3, 3, 3, 8, 9, 3, 6, 4, 3, 4, 3, 3, 10, 4, 3, 4, 6, 4, 4, 3, 3, 3, 3, 5, 3, 3, 3, 10, 3, 3, 4, 3, 5, 4, 4, 5, 5, 3, 3, 4, 3, 3, 4, 7, 3, 4, 15, 3, 3, 3, 3, 3, 4, 4, 3, 3, 3, 5, 4, 3, 3, 3, 4, 3, 5, 3, 6, 4, 3, 5, 4, 3, 4, 5, 3, 15, 3, 3, 3, 3, 4, 3, 3, 3, 8, 4, 3, 3, 4, 8, 3, 3, 7, 3, 3, 3, 14, 3, 7, 5, 3, 3, 6, 6, 3, 3, 3, 4, 4, 4, 3, 3, 3, 3, 3, 6, 5, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3]

# %%
# Epidemic Layer
gamma_e = 4.0 #gamma_e = 4.75   #gamma_e = 4.0
kmin_e = 3
ldeg_e = generate_degree_sequence(n, gamma_e, kmin_e)
print("Degree Sequence: ", ldeg_e)
enw = nx.configuration_model(ldeg_e)
k = ((gamma_e-1)/(gamma_e-2))*(kmin_e) #<k>
k2 =((gamma_e-1)/(gamma_e-3))*((kmin_e)**2) #<k^2>
division_factor = (k2-k)/k # division factor to compute beta_max(<k^2>-<k>)/<k>
print(["<k>: ", k, "<k^2>: ", k2,"(<k^2>-<k>)/<k>: ",  division_factor])
# Out:
# Degree Sequence:  [3, 3, 5, 3, 3, 3, 3, 3, 3, 3, 3, 3, 4, 10, 3, 3, 5, 5, 4, 3, 3, 3, 3, 3, 3, 3, 3, 3, 5, 3, 3, 3, 6, 3, 3, 3, 8, 3, 6, 4, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 4, 3, 3, 3, 3, 3, 6, 3, 3, 3, 4, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3]
# ['<k>: ', 4.5, '<k^2>: ', 27.0, '(<k^2>-<k>)/<k>: ', 5.0]

# %%
from google.colab import drive
drive.mount('/content/drive',force_remount=True)
# Out:
# Mounted at /content/drive

# %%
def ICE_model_record_layer_education(inw, ldeg_i, ltre, cnw, ldeg_c, lprot, enw, ldeg_e, lam, alp, omega, sigma, phi, zeta_1, zeta_2, zeta_3, zeta_4, beta_PP, beta_NP, beta_PN, beta_NN, mu, n_sample):

  t_max = 1000      # Set maximum time
  kmax_i = max (ldeg_i)     # Get maximum hyperedge degree in information layer
  kmax_c = max (ldeg_c)     # Get maximum hyperedge degree in cognition layer
  kmax_e = max (ldeg_e)     # Get maximum degree in epidemic layer
  N = inw.order()  # Get the network size

  rho_A = []   # Keep track of fraction of stifler in information layer
  rho_P = []   # Keep track of fraction of protected in cognition layer
  rho_R = []   # Keep track of fraction of recovered in epidemic layer

  for i_samp in range(1, n_sample + 1):
      t = 0                 # Initialize time, number of corrected, number of recovered
      N_corrected = 0
      N_recovered = 0
      N_stifler = 0

      info_states = {j: "U" for j in inw.nodes()}   # Initialize information and disease states
      disease_states = {k: "S" for k in enw.nodes()}

      lprot = assign_protection(cnw, frac_prot)
      protected = list(filter(lambda node: lprot[node] == "P", lprot))
      N_protected = len(protected)
      not_protected = list(filter(lambda node: lprot[node] == "N", lprot))

      gossip = []     # Create lists to store gossip and corrected individuals in information layer
      corrected = []
      stifler = []

      N_gossip = 0
      N_e_i = 0

      infected = []     # Create lists to store infected and recovered individuals in epidemic layer
      recovered = []

      time_record= [0]
      recovered_count = [0]

      N_infected = 0
      N_e_e = 0
      for _ in range(10):
          ill_node_0 = np.random.choice([node for node, state in disease_states.items() if state == "S" and node in enw.nodes()])
          disease_states[ill_node_0] = "I"
          infected.append(ill_node_0)
          N_infected += 1
          N_e_e += enw.degree(ill_node_0)

      beta_max = max(beta_PP,beta_NP,beta_PN,beta_NN) # Chose the largest infection rate (I known that it is beta_NN, but keep it general)

      while t < 150 and N_infected > 0:   # We stop when there is no infection
        total_rate = lam * N_e_i + 2 * alp * N_e_i + beta_max * N_e_e + mu * N_infected + zeta_1 * N_protected + zeta_2 * (N-N_protected) + zeta_3 * N_protected + zeta_4 * (N-N_protected) + omega * N_stifler + sigma * N_e_i + sigma * N_gossip + phi * N_corrected
        tau = -np.log(np.random.uniform(1e-6, 1)) / total_rate
        t += tau

        if t >= t_max:
                break

      # Determine which event occurs
        event = np.random.uniform()
        p1 = (lam * N_e_i) / total_rate     # rumor spreading
        p2 = (lam * N_e_i + alp * N_e_i) / total_rate  # rumor stifling (by meeting stifling neighbor threshold)
        p3 = (lam * N_e_i + 2 * alp * N_e_i) / total_rate  # rumor stifling (by meeting gossip neighbor threshold)

        p4 = (lam * N_e_i + 2 * alp * N_e_i + beta_max * N_e_e) / total_rate  # disease propagation
        p5 = (lam * N_e_i + 2 * alp * N_e_i + beta_max * N_e_e + mu * N_infected) / total_rate  # disease recovery

        p6 = (lam * N_e_i + 2 * alp * N_e_i + beta_max * N_e_e + mu * N_infected + zeta_1 * N_protected) / total_rate # change to not adopting protection by information
        p7 = (lam * N_e_i + 2 * alp * N_e_i + beta_max * N_e_e + mu * N_infected + zeta_1 * N_protected + zeta_2 * (N-N_protected) ) / total_rate # change to adopting protection by information
        p8 = (lam * N_e_i + 2 * alp * N_e_i + beta_max * N_e_e + mu * N_infected + zeta_1 * N_protected + zeta_2 * (N-N_protected)  + zeta_3 * N_protected) / total_rate # change to not adopting protection by neighborhood behavior
        p9 = (lam * N_e_i + 2 * alp * N_e_i + beta_max * N_e_e + mu * N_infected + zeta_1 * N_protected + zeta_2 * (N-N_protected) + zeta_3 * N_protected + zeta_4 * (N-N_protected))/total_rate # change to adopting protection by neighborhood behavior
        p10 = (lam * N_e_i + 2 * alp * N_e_i + beta_max * N_e_e + mu * N_infected + zeta_1 * N_protected + zeta_2 * (N-N_protected) + zeta_3 * N_protected + zeta_4 * (N-N_protected) + omega * N_stifler)/total_rate # rumor interest renewal
        p11 = (lam * N_e_i + 2 * alp * N_e_i + beta_max * N_e_e + mu * N_infected + zeta_1 * N_protected + zeta_2 * (N-N_protected) + zeta_3 * N_protected + zeta_4 * (N-N_protected) + omega * N_stifler + sigma * N_e_i)/total_rate # gossip correction by education
        p12 = (lam * N_e_i + 2 * alp * N_e_i + beta_max * N_e_e + mu * N_infected + zeta_1 * N_protected + zeta_2 * (N-N_protected) + zeta_3 * N_protected + zeta_4 * (N-N_protected) + omega * N_stifler + sigma * N_e_i + sigma * N_gossip)/total_rate # gossip correction from outside
        # >p12 relapse after correction

        # Determine if accept selected individual based on degree distribution
        q_deg_i = np.random.uniform()
        q_deg_c = np.random.uniform()
        q_deg_e = np.random.uniform()

        # Case 1: Rumor spreading
        if event < p1:
                response='F'
                while len(gossip)>0 and response =='F':
                  gossip_node = np.random.choice(gossip) #chose an infected node proportional to the degree
                  draw_rn = np.random.uniform()
                  if draw_rn < inw.degree(gossip_node)/kmax_i:
                     response='T'

                edges_containing_gossip = [edge for edge in inw.edges() if gossip_node in inw[edge]]
                if edges_containing_gossip:
                        rumor_hyper_edge = np.random.choice(edges_containing_gossip)
                        neighbors = inw[rumor_hyper_edge]
                        for neighbor in neighbors:
                            if info_states[neighbor] == "U":
                                count_gossip_neighbors = sum(1 for node in inw.neighbors(neighbor) if info_states[node] == "G")
                                if count_gossip_neighbors / len(inw.neighbors(neighbor)) >= ltre[neighbor]:
                                    info_states[neighbor] = "G"  # uninformed neighbor becomes gossip spreader
                                    gossip.append(neighbor)
                                    N_gossip += 1
                                    N_e_i += inw.degree(neighbor)


        # Case 2: Rumor stifling (by meeting stifling neighbor threshold)
        elif event < p2:
                    response='F'
                    while len(gossip)>0 and response =='F':
                      stifler_node = np.random.choice(gossip) #chose an infected node proportional to the degree
                      draw_rn = np.random.uniform()
                      if draw_rn < inw.degree(stifler_node)/kmax_i:
                         response='T'

                    stifler_hyper_edge = np.random.choice(list(inw.edges()))
                    neighbors = inw[stifler_hyper_edge]
                    count_stifler_neighbors = sum(1 for node in inw.neighbors(stifler_node) if info_states[node] == "A")
                    if count_stifler_neighbors > 0:
                            info_states[stifler_node] = "A"
                            N_gossip -= 1
                            gossip.remove(stifler_node)
                            stifler.append(stifler_node)
                            N_stifler += 1
                            N_e_i -= inw.degree(stifler_node)


        # Case 3: Rumor stifling (by meeting gossip neighbor threshold)
        elif event < p3:
                    response='F'
                    while len(gossip)>0 and response =='F':
                      stifler_node = np.random.choice(gossip) #chose an infected node proportional to the degree
                      draw_rn = np.random.uniform()
                      if draw_rn < inw.degree(stifler_node)/kmax_i:
                         response='T'

                    stifler_hyper_edge = np.random.choice(list(inw.edges()))
                    neighbors = inw[stifler_hyper_edge]
                    count_gossip_neighbors = sum(1 for node in inw.neighbors(stifler_node) if info_states[node] == "G")
                    if count_gossip_neighbors > 0:
                            info_states[stifler_node] = "A"
                            N_gossip -= 1
                            gossip.remove(stifler_node)
                            stifler.append(stifler_node)
                            N_stifler += 1
                            N_e_i -= inw.degree(stifler_node)

        # Case 4: Disease propagation
        elif event < p4:
            # code based on the new pseudo code
            response='F'
            while len(infected)>0 and response =='F':  #draw node until degree distribution is reached and while the infected list is not empty
              infected_node = np.random.choice(infected) #choose an infected node proportional to the degree
              draw_rn = np.random.uniform()
              if draw_rn < enw.degree(infected_node)/kmax_e: # kmax_e is the global max degree
                 response='T'

            neighbors = list(enw.neighbors(infected_node)) #get the list of neighbors of the infected node
            target_node = np.random.choice(neighbors) #choose a neighbor at random
            # beta_NN > beta_PN > beta_NP > beta_PP
            if disease_states[target_node] == "S":
                if lprot[target_node] == "P" and lprot[infected_node] == "P":
                   beta_correct = beta_PP
                elif lprot[target_node] == "N" and lprot[infected_node] == "P":
                   beta_correct = beta_NP
                elif lprot[target_node] == "P" and lprot[infected_node] == "N":
                   beta_correct = beta_PN
                else:
                   beta_correct = beta_NN

                draw_rn = np.random.uniform()
                if draw_rn < beta_correct/beta_max:
                   disease_states[target_node] = "I"
                   infected.append(target_node)
                   N_infected += 1
                   N_e_e += enw.degree(target_node)

                   ## Start gossip after epidemic have started
                   if N_gossip == 0:
                      uninformed = [node for node, state in info_states.items() if state == "U" and node in inw.nodes()]
                      if len(uninformed) > 0:
                        rumor_node_0 = np.random.choice(uninformed)
                        info_states[rumor_node_0] = "G"
                        gossip.append(rumor_node_0)
                        N_gossip += 1
                        N_e_i += inw.degree(rumor_node_0)


        # Case 5: Disease recovery
        elif event < p5:
                  recovered_node = np.random.choice(infected)
                  disease_states[recovered_node] = "R"
                  infected.remove(recovered_node)
                  recovered.append(recovered_node)
                  N_infected -= 1
                  N_recovered += 1
                  N_e_e -= enw.degree(recovered_node)
                  time_record.append(t)
                  recovered_count.append(N_recovered)

        # Case 6: # Change to not adopting protection based on information layer
        # n_G is the total spreader neighbors on the information layer,
        # while k_info is the total neighbor count on the information layer
        elif event < p6:
            if len(protected) > 0:
              node_to_not_protect = np.random.choice(protected)
              n_G = sum(1 for node in filter(lambda x: info_states[x] == "G", inw.neighbors(node_to_not_protect)))
              k_info = len(list(inw.neighbors(node_to_not_protect)))
              frac_inf = N_infected/N
              b = 3
              if np.random.uniform() < (n_G / k_info) * (1-np.tanh(b*(frac_inf))):
                    lprot[node_to_not_protect] = "N"
                    protected.remove(node_to_not_protect)
                    not_protected.append(node_to_not_protect)
                    N_protected -= 1


        # Case 7: Change to adopting protection based on information layer
        elif event < p7:
            if len(not_protected) > 0:
                node_to_protect = np.random.choice(not_protected)
                n_G = sum(1 for node in filter(lambda x: info_states[x] == "G", inw.neighbors(node_to_protect)))
                k_info = len(list(inw.neighbors(node_to_protect)))
                frac_inf = N_infected/N
                b = 3
                if np.random.uniform() < (1 - n_G / k_info) * np.tanh(b*(frac_inf)):
                        lprot[node_to_protect] = "P"
                        not_protected.remove(node_to_protect)
                        protected.append(node_to_protect)
                        N_protected += 1

        # Case 8: # Change to not adopting protection based on neighborhood behavior in cognition layer
        # n_P is the total protected neighbors on the cognition layer,
        # while k_cog is the total neighbor count on the cognition layer
        elif event < p8:
            if len(protected) > 0:
                node_to_not_protect = np.random.choice(protected)
                n_P = sum(1 for node in filter(lambda x: lprot[x] == "P", cnw.neighbors(node_to_not_protect)))
                k_cog = len(list(cnw.neighbors(node_to_not_protect)))
                if np.random.uniform() < 1 - n_P / k_cog:
                        lprot[node_to_not_protect] = "N"
                        protected.remove(node_to_not_protect)
                        not_protected.append(node_to_not_protect)
                        N_protected -= 1

        # Case 9: # Change to adopting protection based on neighborhood behavior in cognition layer
        elif event < p9:
            if len(not_protected) > 0:
                node_to_protect = np.random.choice(not_protected)
                n_P = sum(1 for node in filter(lambda x: lprot[x] == "P", cnw.neighbors(node_to_protect)))
                k_cog = len(list(cnw.neighbors(node_to_protect)))
                if np.random.uniform() < n_P / k_cog:
                        lprot[node_to_protect] = "P"
                        not_protected.remove(node_to_protect)
                        protected.append(node_to_protect)
                        N_protected += 1

        # Case 10: Rumor interest renewal
        elif event < p10:
            if len(stifler) > 0:
                  stifler_node = np.random.choice(stifler)
                  info_states[stifler_node] = "U"
                  stifler.remove(stifler_node)
                  N_stifler -= 1

        # Case 11: Correction of rumor by education G+C->C+C
        elif event < p11:
                    response='F'
                    while len(gossip)>0 and response =='F':
                      target_node = np.random.choice(gossip)
                      draw_rn = np.random.uniform()
                      if draw_rn < inw.degree(target_node)/kmax_i:
                         response='T'

                    target_hyper_edge = np.random.choice(list(inw.edges()))
                    neighbors = inw[target_hyper_edge]
                    count_corrected_neighbors = sum(1 for node in inw.neighbors(target_node) if info_states[node] == "C")
                    if count_corrected_neighbors > 0:
                            info_states[target_node] = "C"
                            N_gossip -= 1
                            gossip.remove(target_node)
                            corrected.append(target_node)
                            N_corrected += 1
                            N_e_i -= inw.degree(target_node)

        # Case 12: Correction of rumor from outside G->C
        elif event < p12:
            if len(gossip)>0:
                correction_node = np.random.choice(gossip)
                info_states[correction_node] = "C"
                N_gossip -= 1
                gossip.remove(correction_node)
                corrected.append(correction_node)
                N_corrected += 1
                N_e_i -= inw.degree(correction_node)

        # Case 13: Corrected become stifler
        else:
          if len(corrected)>0:
                new_exposure_node = np.random.choice(corrected)
                info_states[new_exposure_node] = "A"
                N_corrected -= 1
                corrected.remove(new_exposure_node)
                N_stifler += 1
                stifler.append(new_exposure_node)

  return time_record, recovered_count

# %%
# No Control single run
lam = 1/3
alp = 1/3
#omega = 1.4
#sigma = 1/10
phi = 1/5
zeta_1 = 0.2 #go to not protect by information
zeta_2 = 0.2 #go to protect by information
zeta_3 = 0 #go to not protect by neighborhood behavior
zeta_4 = 0 #go to protect by neighborhood behavior

mu = 0.2
R0 = 4.0 #(assume a COVID19-like disease for the reproduction number) #2.0 # reproduction number
beta_NN = R0 * mu / division_factor
beta_PN = beta_NN * 0.2
beta_NP = beta_NN * 0.1
beta_PP = beta_NN * 0.0
n_sample = 1

# %%
import multiprocessing as mp

n_iterations = 100

omega_range = np.round([i * 0.10 for i in range(21)], 3)
sigma_range = np.round([i * 0.025 for i in range(21)], 3)

heatmap_data = np.zeros((len(omega_range), len(sigma_range)))

def compute_attack_rate(params):
    omega, sigma = params
    recovered_counts = []

    for _ in range(n_iterations):
        time_record, recovered_count = ICE_model_record_layer_education(
            inw, ldeg_i, ltre, cnw, ldeg_c, lprot, enw, ldeg_e, lam, alp, omega, sigma,
            phi, zeta_1, zeta_2, zeta_3, zeta_4, beta_PP, beta_NP, beta_PN, beta_NN, mu, n_sample
        )
        final_recovered_count = recovered_count[-1]
        recovered_counts.append(final_recovered_count)

    attack_rate = np.mean(recovered_counts) / 500
    return omega, sigma, attack_rate

params_list = [(omega, sigma) for omega in omega_range for sigma in sigma_range]

with mp.Pool(processes=mp.cpu_count()) as pool:
    results = pool.map(compute_attack_rate, params_list)

for omega, sigma, attack_rate in results:
    i = np.where(omega_range == omega)[0][0]
    j = np.where(sigma_range == sigma)[0][0]
    heatmap_data[i, j] = attack_rate
    print(f"Omega: {omega}, Sigma: {sigma}, Attack Rate: {attack_rate}")


# Store data
import csv
file_path = '/content/drive/My Drive/Information_Behavior_Disease_Networks/heat_map_results/Fig_7B_more_steps.csv'
with open(file_path, 'w', newline='') as file:
    writer = csv.writer(file)

    header = ['Omega \\ Sigma'] + sigma_range.tolist()
    writer.writerow(header)

    for i, omega in enumerate(omega_range):
        row = [omega] + heatmap_data[i].tolist()
        writer.writerow(row)

print(f"Data has been written.")
# Out:
# Omega: 0.0, Sigma: 0.0, Attack Rate: 0.10507999999999999
# Omega: 0.0, Sigma: 0.025, Attack Rate: 0.10024
# Omega: 0.0, Sigma: 0.05, Attack Rate: 0.10222
# Omega: 0.0, Sigma: 0.075, Attack Rate: 0.10446
# Omega: 0.0, Sigma: 0.1, Attack Rate: 0.10002
# Omega: 0.0, Sigma: 0.125, Attack Rate: 0.10384
# Omega: 0.0, Sigma: 0.15, Attack Rate: 0.10658
# Omega: 0.0, Sigma: 0.175, Attack Rate: 0.10482
# Omega: 0.0, Sigma: 0.2, Attack Rate: 0.10212
# Omega: 0.0, Sigma: 0.225, Attack Rate: 0.10558
# Omega: 0.0, Sigma: 0.25, Attack Rate: 0.10192
# Omega: 0.0, Sigma: 0.275, Attack Rate: 0.10529999999999999
# Omega: 0.0, Sigma: 0.3, Attack Rate: 0.10687999999999999
# Omega: 0.0, Sigma: 0.325, Attack Rate: 0.10886
# Omega: 0.0, Sigma: 0.35, Attack Rate: 0.10364
# Omega: 0.0, Sigma: 0.375, Attack Rate: 0.09638
# Omega: 0.0, Sigma: 0.4, Attack Rate: 0.1002
# Omega: 0.0, Sigma: 0.425, Attack Rate: 0.10658
# Omega: 0.0, Sigma: 0.45, Attack Rate: 0.09831999999999999
# Omega: 0.0, Sigma: 0.475, Attack Rate: 0.10276
# Omega: 0.0, Sigma: 0.5, Attack Rate: 0.09978000000000001
# Omega: 0.1, Sigma: 0.0, Attack Rate: 0.11037999999999999
# Omega: 0.1, Sigma: 0.025, Attack Rate: 0.10478
# Omega: 0.1, Sigma: 0.05, Attack Rate: 0.11106
# Omega: 0.1, Sigma: 0.075, Attack Rate: 0.1025
# Omega: 0.1, Sigma: 0.1, Attack Rate: 0.10235999999999999
# Omega: 0.1, Sigma: 0.125, Attack Rate: 0.10457999999999999
# Omega: 0.1, Sigma: 0.15, Attack Rate: 0.10436
# Omega: 0.1, Sigma: 0.175, Attack Rate: 0.10166
# Omega: 0.1, Sigma: 0.2, Attack Rate: 0.10851999999999999
# Omega: 0.1, Sigma: 0.225, Attack Rate: 0.10142
# Omega: 0.1, Sigma: 0.25, Attack Rate: 0.10214
# Omega: 0.1, Sigma: 0.275, Attack Rate: 0.10498
# Omega: 0.1, Sigma: 0.3, Attack Rate: 0.10446
# Omega: 0.1, Sigma: 0.325, Attack Rate: 0.10308
# Omega: 0.1, Sigma: 0.35, Attack Rate: 0.10598
# Omega: 0.1, Sigma: 0.375, Attack Rate: 0.11218
# Omega: 0.1, Sigma: 0.4, Attack Rate: 0.10078
# Omega: 0.1, Sigma: 0.425, Attack Rate: 0.10598
# Omega: 0.1, Sigma: 0.45, Attack Rate: 0.1013
# Omega: 0.1, Sigma: 0.475, Attack Rate: 0.09868
# Omega: 0.1, Sigma: 0.5, Attack Rate: 0.10074
# Omega: 0.2, Sigma: 0.0, Attack Rate: 0.11372
# Omega: 0.2, Sigma: 0.025, Attack Rate: 0.10386
# Omega: 0.2, Sigma: 0.05, Attack Rate: 0.10118
# Omega: 0.2, Sigma: 0.075, Attack Rate: 0.10804000000000001
# Omega: 0.2, Sigma: 0.1, Attack Rate: 0.10132
# Omega: 0.2, Sigma: 0.125, Attack Rate: 0.10736
# Omega: 0.2, Sigma: 0.15, Attack Rate: 0.10432
# Omega: 0.2, Sigma: 0.175, Attack Rate: 0.09898
# Omega: 0.2, Sigma: 0.2, Attack Rate: 0.10504000000000001
# Omega: 0.2, Sigma: 0.225, Attack Rate: 0.11116
# Omega: 0.2, Sigma: 0.25, Attack Rate: 0.10448
# Omega: 0.2, Sigma: 0.275, Attack Rate: 0.10132
# Omega: 0.2, Sigma: 0.3, Attack Rate: 0.11068
# Omega: 0.2, Sigma: 0.325, Attack Rate: 0.10308
# Omega: 0.2, Sigma: 0.35, Attack Rate: 0.10194
# Omega: 0.2, Sigma: 0.375, Attack Rate: 0.10656
# Omega: 0.2, Sigma: 0.4, Attack Rate: 0.10046
# Omega: 0.2, Sigma: 0.425, Attack Rate: 0.0998
# Omega: 0.2, Sigma: 0.45, Attack Rate: 0.10246
# Omega: 0.2, Sigma: 0.475, Attack Rate: 0.10532
# Omega: 0.2, Sigma: 0.5, Attack Rate: 0.10516
# Omega: 0.3, Sigma: 0.0, Attack Rate: 0.11386
# Omega: 0.3, Sigma: 0.025, Attack Rate: 0.11394
# Omega: 0.3, Sigma: 0.05, Attack Rate: 0.10715999999999999
# Omega: 0.3, Sigma: 0.075, Attack Rate: 0.11176
# Omega: 0.3, Sigma: 0.1, Attack Rate: 0.10304
# Omega: 0.3, Sigma: 0.125, Attack Rate: 0.10058
# Omega: 0.3, Sigma: 0.15, Attack Rate: 0.11204
# Omega: 0.3, Sigma: 0.175, Attack Rate: 0.11056
# Omega: 0.3, Sigma: 0.2, Attack Rate: 0.10588
# Omega: 0.3, Sigma: 0.225, Attack Rate: 0.11166
# Omega: 0.3, Sigma: 0.25, Attack Rate: 0.10808
# Omega: 0.3, Sigma: 0.275, Attack Rate: 0.107
# Omega: 0.3, Sigma: 0.3, Attack Rate: 0.10526
# Omega: 0.3, Sigma: 0.325, Attack Rate: 0.09998
# Omega: 0.3, Sigma: 0.35, Attack Rate: 0.10812000000000001
# Omega: 0.3, Sigma: 0.375, Attack Rate: 0.11184000000000001
# Omega: 0.3, Sigma: 0.4, Attack Rate: 0.10162
# Omega: 0.3, Sigma: 0.425, Attack Rate: 0.1062
# Omega: 0.3, Sigma: 0.45, Attack Rate: 0.10106
# Omega: 0.3, Sigma: 0.475, Attack Rate: 0.09826
# Omega: 0.3, Sigma: 0.5, Attack Rate: 0.10606
# Omega: 0.4, Sigma: 0.0, Attack Rate: 0.11023999999999999
# Omega: 0.4, Sigma: 0.025, Attack Rate: 0.10794
# Omega: 0.4, Sigma: 0.05, Attack Rate: 0.10951999999999999
# Omega: 0.4, Sigma: 0.075, Attack Rate: 0.10412
# Omega: 0.4, Sigma: 0.1, Attack Rate: 0.11037999999999999
# Omega: 0.4, Sigma: 0.125, Attack Rate: 0.11062000000000001
# Omega: 0.4, Sigma: 0.15, Attack Rate: 0.10122
# Omega: 0.4, Sigma: 0.175, Attack Rate: 0.10686
# Omega: 0.4, Sigma: 0.2, Attack Rate: 0.10496
# Omega: 0.4, Sigma: 0.225, Attack Rate: 0.104
# Omega: 0.4, Sigma: 0.25, Attack Rate: 0.10414
# Omega: 0.4, Sigma: 0.275, Attack Rate: 0.10768000000000001
# Omega: 0.4, Sigma: 0.3, Attack Rate: 0.10136
# Omega: 0.4, Sigma: 0.325, Attack Rate: 0.10404000000000001
# Omega: 0.4, Sigma: 0.35, Attack Rate: 0.10562
# Omega: 0.4, Sigma: 0.375, Attack Rate: 0.10206
# Omega: 0.4, Sigma: 0.4, Attack Rate: 0.1072
# Omega: 0.4, Sigma: 0.425, Attack Rate: 0.10718000000000001
# Omega: 0.4, Sigma: 0.45, Attack Rate: 0.10679999999999999
# Omega: 0.4, Sigma: 0.475, Attack Rate: 0.10556
# Omega: 0.4, Sigma: 0.5, Attack Rate: 0.1043
# Omega: 0.5, Sigma: 0.0, Attack Rate: 0.11926
# Omega: 0.5, Sigma: 0.025, Attack Rate: 0.11236
# Omega: 0.5, Sigma: 0.05, Attack Rate: 0.11636
# Omega: 0.5, Sigma: 0.075, Attack Rate: 0.111
# Omega: 0.5, Sigma: 0.1, Attack Rate: 0.10654000000000001
# Omega: 0.5, Sigma: 0.125, Attack Rate: 0.11064
# Omega: 0.5, Sigma: 0.15, Attack Rate: 0.11008
# Omega: 0.5, Sigma: 0.175, Attack Rate: 0.10751999999999999
# Omega: 0.5, Sigma: 0.2, Attack Rate: 0.10298
# Omega: 0.5, Sigma: 0.225, Attack Rate: 0.1118
# Omega: 0.5, Sigma: 0.25, Attack Rate: 0.10926000000000001
# Omega: 0.5, Sigma: 0.275, Attack Rate: 0.1005
# Omega: 0.5, Sigma: 0.3, Attack Rate: 0.10928
# Omega: 0.5, Sigma: 0.325, Attack Rate: 0.10538
# Omega: 0.5, Sigma: 0.35, Attack Rate: 0.09928000000000001
# Omega: 0.5, Sigma: 0.375, Attack Rate: 0.101
# Omega: 0.5, Sigma: 0.4, Attack Rate: 0.0993
# Omega: 0.5, Sigma: 0.425, Attack Rate: 0.10868000000000001
# Omega: 0.5, Sigma: 0.45, Attack Rate: 0.10376
# Omega: 0.5, Sigma: 0.475, Attack Rate: 0.10538
# Omega: 0.5, Sigma: 0.5, Attack Rate: 0.10916
# Omega: 0.6, Sigma: 0.0, Attack Rate: 0.12572
# Omega: 0.6, Sigma: 0.025, Attack Rate: 0.11581999999999999
# Omega: 0.6, Sigma: 0.05, Attack Rate: 0.1119
# Omega: 0.6, Sigma: 0.075, Attack Rate: 0.11326
# Omega: 0.6, Sigma: 0.1, Attack Rate: 0.1197
# Omega: 0.6, Sigma: 0.125, Attack Rate: 0.1113
# Omega: 0.6, Sigma: 0.15, Attack Rate: 0.10006
# Omega: 0.6, Sigma: 0.175, Attack Rate: 0.10942
# Omega: 0.6, Sigma: 0.2, Attack Rate: 0.10784
# Omega: 0.6, Sigma: 0.225, Attack Rate: 0.10066
# Omega: 0.6, Sigma: 0.25, Attack Rate: 0.10398
# Omega: 0.6, Sigma: 0.275, Attack Rate: 0.10254
# Omega: 0.6, Sigma: 0.3, Attack Rate: 0.10398
# Omega: 0.6, Sigma: 0.325, Attack Rate: 0.10436
# Omega: 0.6, Sigma: 0.35, Attack Rate: 0.10507999999999999
# Omega: 0.6, Sigma: 0.375, Attack Rate: 0.11095999999999999
# Omega: 0.6, Sigma: 0.4, Attack Rate: 0.10601999999999999
# Omega: 0.6, Sigma: 0.425, Attack Rate: 0.10914
# Omega: 0.6, Sigma: 0.45, Attack Rate: 0.10276
# Omega: 0.6, Sigma: 0.475, Attack Rate: 0.10432
# Omega: 0.6, Sigma: 0.5, Attack Rate: 0.11122
# Omega: 0.7, Sigma: 0.0, Attack Rate: 0.11692
# Omega: 0.7, Sigma: 0.025, Attack Rate: 0.12504
# Omega: 0.7, Sigma: 0.05, Attack Rate: 0.11858
# Omega: 0.7, Sigma: 0.075, Attack Rate: 0.11152
# Omega: 0.7, Sigma: 0.1, Attack Rate: 0.11596
# Omega: 0.7, Sigma: 0.125, Attack Rate: 0.10886
# Omega: 0.7, Sigma: 0.15, Attack Rate: 0.11164
# Omega: 0.7, Sigma: 0.175, Attack Rate: 0.10986
# Omega: 0.7, Sigma: 0.2, Attack Rate: 0.10507999999999999
# Omega: 0.7, Sigma: 0.225, Attack Rate: 0.10981999999999999
# Omega: 0.7, Sigma: 0.25, Attack Rate: 0.11252
# Omega: 0.7, Sigma: 0.275, Attack Rate: 0.10973999999999999
# Omega: 0.7, Sigma: 0.3, Attack Rate: 0.10582
# Omega: 0.7, Sigma: 0.325, Attack Rate: 0.10865999999999999
# Omega: 0.7, Sigma: 0.35, Attack Rate: 0.10532
# Omega: 0.7, Sigma: 0.375, Attack Rate: 0.10318000000000001
# Omega: 0.7, Sigma: 0.4, Attack Rate: 0.10124
# Omega: 0.7, Sigma: 0.425, Attack Rate: 0.10916
# Omega: 0.7, Sigma: 0.45, Attack Rate: 0.10128
# Omega: 0.7, Sigma: 0.475, Attack Rate: 0.10376
# Omega: 0.7, Sigma: 0.5, Attack Rate: 0.11118
# Omega: 0.8, Sigma: 0.0, Attack Rate: 0.12272
# Omega: 0.8, Sigma: 0.025, Attack Rate: 0.12714
# Omega: 0.8, Sigma: 0.05, Attack Rate: 0.11692
# Omega: 0.8, Sigma: 0.075, Attack Rate: 0.1211
# Omega: 0.8, Sigma: 0.1, Attack Rate: 0.1193
# Omega: 0.8, Sigma: 0.125, Attack Rate: 0.10973999999999999
# Omega: 0.8, Sigma: 0.15, Attack Rate: 0.108
# Omega: 0.8, Sigma: 0.175, Attack Rate: 0.10779999999999999
# Omega: 0.8, Sigma: 0.2, Attack Rate: 0.10718000000000001
# Omega: 0.8, Sigma: 0.225, Attack Rate: 0.10690000000000001
# Omega: 0.8, Sigma: 0.25, Attack Rate: 0.10751999999999999
# Omega: 0.8, Sigma: 0.275, Attack Rate: 0.10622
# Omega: 0.8, Sigma: 0.3, Attack Rate: 0.10392
# Omega: 0.8, Sigma: 0.325, Attack Rate: 0.10848000000000001
# Omega: 0.8, Sigma: 0.35, Attack Rate: 0.10715999999999999
# Omega: 0.8, Sigma: 0.375, Attack Rate: 0.10156
# Omega: 0.8, Sigma: 0.4, Attack Rate: 0.11104
# Omega: 0.8, Sigma: 0.425, Attack Rate: 0.09942000000000001
# Omega: 0.8, Sigma: 0.45, Attack Rate: 0.10334
# Omega: 0.8, Sigma: 0.475, Attack Rate: 0.10678
# Omega: 0.8, Sigma: 0.5, Attack Rate: 0.10529999999999999
# Omega: 0.9, Sigma: 0.0, Attack Rate: 0.12064
# Omega: 0.9, Sigma: 0.025, Attack Rate: 0.12312000000000001
# Omega: 0.9, Sigma: 0.05, Attack Rate: 0.1185
# Omega: 0.9, Sigma: 0.075, Attack Rate: 0.11896
# Omega: 0.9, Sigma: 0.1, Attack Rate: 0.11276
# Omega: 0.9, Sigma: 0.125, Attack Rate: 0.12146
# Omega: 0.9, Sigma: 0.15, Attack Rate: 0.1163
# Omega: 0.9, Sigma: 0.175, Attack Rate: 0.11134000000000001
# Omega: 0.9, Sigma: 0.2, Attack Rate: 0.10482
# Omega: 0.9, Sigma: 0.225, Attack Rate: 0.10134
# Omega: 0.9, Sigma: 0.25, Attack Rate: 0.10524
# Omega: 0.9, Sigma: 0.275, Attack Rate: 0.11416
# Omega: 0.9, Sigma: 0.3, Attack Rate: 0.10951999999999999
# Omega: 0.9, Sigma: 0.325, Attack Rate: 0.10936
# Omega: 0.9, Sigma: 0.35, Attack Rate: 0.10386
# Omega: 0.9, Sigma: 0.375, Attack Rate: 0.104
# Omega: 0.9, Sigma: 0.4, Attack Rate: 0.10834
# Omega: 0.9, Sigma: 0.425, Attack Rate: 0.10466
# Omega: 0.9, Sigma: 0.45, Attack Rate: 0.10244
# Omega: 0.9, Sigma: 0.475, Attack Rate: 0.10590000000000001
# Omega: 0.9, Sigma: 0.5, Attack Rate: 0.10086
# Omega: 1.0, Sigma: 0.0, Attack Rate: 0.13372
# Omega: 1.0, Sigma: 0.025, Attack Rate: 0.12301999999999999
# Omega: 1.0, Sigma: 0.05, Attack Rate: 0.12176000000000001
# Omega: 1.0, Sigma: 0.075, Attack Rate: 0.11888
# Omega: 1.0, Sigma: 0.1, Attack Rate: 0.11962
# Omega: 1.0, Sigma: 0.125, Attack Rate: 0.11312
# Omega: 1.0, Sigma: 0.15, Attack Rate: 0.10826000000000001
# Omega: 1.0, Sigma: 0.175, Attack Rate: 0.10944
# Omega: 1.0, Sigma: 0.2, Attack Rate: 0.11154
# Omega: 1.0, Sigma: 0.225, Attack Rate: 0.1107
# Omega: 1.0, Sigma: 0.25, Attack Rate: 0.11216
# Omega: 1.0, Sigma: 0.275, Attack Rate: 0.11109999999999999
# Omega: 1.0, Sigma: 0.3, Attack Rate: 0.10592
# Omega: 1.0, Sigma: 0.325, Attack Rate: 0.1037
# Omega: 1.0, Sigma: 0.35, Attack Rate: 0.11118
# Omega: 1.0, Sigma: 0.375, Attack Rate: 0.10945999999999999
# Omega: 1.0, Sigma: 0.4, Attack Rate: 0.10726000000000001
# Omega: 1.0, Sigma: 0.425, Attack Rate: 0.10715999999999999
# Omega: 1.0, Sigma: 0.45, Attack Rate: 0.114
# Omega: 1.0, Sigma: 0.475, Attack Rate: 0.10815999999999999
# Omega: 1.0, Sigma: 0.5, Attack Rate: 0.105
# Omega: 1.1, Sigma: 0.0, Attack Rate: 0.13154
# Omega: 1.1, Sigma: 0.025, Attack Rate: 0.12656
# Omega: 1.1, Sigma: 0.05, Attack Rate: 0.1225
# Omega: 1.1, Sigma: 0.075, Attack Rate: 0.12395999999999999
# Omega: 1.1, Sigma: 0.1, Attack Rate: 0.11702
# Omega: 1.1, Sigma: 0.125, Attack Rate: 0.1178
# Omega: 1.1, Sigma: 0.15, Attack Rate: 0.1077
# Omega: 1.1, Sigma: 0.175, Attack Rate: 0.11001999999999999
# Omega: 1.1, Sigma: 0.2, Attack Rate: 0.11144
# Omega: 1.1, Sigma: 0.225, Attack Rate: 0.107
# Omega: 1.1, Sigma: 0.25, Attack Rate: 0.1066
# Omega: 1.1, Sigma: 0.275, Attack Rate: 0.11104
# Omega: 1.1, Sigma: 0.3, Attack Rate: 0.11128
# Omega: 1.1, Sigma: 0.325, Attack Rate: 0.10394
# Omega: 1.1, Sigma: 0.35, Attack Rate: 0.1038
# Omega: 1.1, Sigma: 0.375, Attack Rate: 0.10878
# Omega: 1.1, Sigma: 0.4, Attack Rate: 0.10798
# Omega: 1.1, Sigma: 0.425, Attack Rate: 0.10887999999999999
# Omega: 1.1, Sigma: 0.45, Attack Rate: 0.0969
# Omega: 1.1, Sigma: 0.475, Attack Rate: 0.1113
# Omega: 1.1, Sigma: 0.5, Attack Rate: 0.1093
# Omega: 1.2, Sigma: 0.0, Attack Rate: 0.12941999999999998
# Omega: 1.2, Sigma: 0.025, Attack Rate: 0.1363
# Omega: 1.2, Sigma: 0.05, Attack Rate: 0.124
# Omega: 1.2, Sigma: 0.075, Attack Rate: 0.12029999999999999
# Omega: 1.2, Sigma: 0.1, Attack Rate: 0.11982
# Omega: 1.2, Sigma: 0.125, Attack Rate: 0.11848
# Omega: 1.2, Sigma: 0.15, Attack Rate: 0.10778
# Omega: 1.2, Sigma: 0.175, Attack Rate: 0.11286
# Omega: 1.2, Sigma: 0.2, Attack Rate: 0.10456
# Omega: 1.2, Sigma: 0.225, Attack Rate: 0.10384
# Omega: 1.2, Sigma: 0.25, Attack Rate: 0.11356000000000001
# Omega: 1.2, Sigma: 0.275, Attack Rate: 0.10662
# Omega: 1.2, Sigma: 0.3, Attack Rate: 0.10804000000000001
# Omega: 1.2, Sigma: 0.325, Attack Rate: 0.1039
# Omega: 1.2, Sigma: 0.35, Attack Rate: 0.1025
# Omega: 1.2, Sigma: 0.375, Attack Rate: 0.10156
# Omega: 1.2, Sigma: 0.4, Attack Rate: 0.10990000000000001
# Omega: 1.2, Sigma: 0.425, Attack Rate: 0.10736
# Omega: 1.2, Sigma: 0.45, Attack Rate: 0.10951999999999999
# Omega: 1.2, Sigma: 0.475, Attack Rate: 0.10456
# Omega: 1.2, Sigma: 0.5, Attack Rate: 0.10008
# Omega: 1.3, Sigma: 0.0, Attack Rate: 0.13774
# Omega: 1.3, Sigma: 0.025, Attack Rate: 0.12846000000000002
# Omega: 1.3, Sigma: 0.05, Attack Rate: 0.12536
# Omega: 1.3, Sigma: 0.075, Attack Rate: 0.12532
# Omega: 1.3, Sigma: 0.1, Attack Rate: 0.12034
# Omega: 1.3, Sigma: 0.125, Attack Rate: 0.12082
# Omega: 1.3, Sigma: 0.15, Attack Rate: 0.1113
# Omega: 1.3, Sigma: 0.175, Attack Rate: 0.11486
# Omega: 1.3, Sigma: 0.2, Attack Rate: 0.10828
# Omega: 1.3, Sigma: 0.225, Attack Rate: 0.11408
# Omega: 1.3, Sigma: 0.25, Attack Rate: 0.10586
# Omega: 1.3, Sigma: 0.275, Attack Rate: 0.11666
# Omega: 1.3, Sigma: 0.3, Attack Rate: 0.11220000000000001
# Omega: 1.3, Sigma: 0.325, Attack Rate: 0.10876000000000001
# Omega: 1.3, Sigma: 0.35, Attack Rate: 0.10565999999999999
# Omega: 1.3, Sigma: 0.375, Attack Rate: 0.10402
# Omega: 1.3, Sigma: 0.4, Attack Rate: 0.10422
# Omega: 1.3, Sigma: 0.425, Attack Rate: 0.10432
# Omega: 1.3, Sigma: 0.45, Attack Rate: 0.10376
# Omega: 1.3, Sigma: 0.475, Attack Rate: 0.09866
# Omega: 1.3, Sigma: 0.5, Attack Rate: 0.11078
# Omega: 1.4, Sigma: 0.0, Attack Rate: 0.14118
# Omega: 1.4, Sigma: 0.025, Attack Rate: 0.11844
# Omega: 1.4, Sigma: 0.05, Attack Rate: 0.1335
# Omega: 1.4, Sigma: 0.075, Attack Rate: 0.12092
# Omega: 1.4, Sigma: 0.1, Attack Rate: 0.12074
# Omega: 1.4, Sigma: 0.125, Attack Rate: 0.12028
# Omega: 1.4, Sigma: 0.15, Attack Rate: 0.11414
# Omega: 1.4, Sigma: 0.175, Attack Rate: 0.11108
# Omega: 1.4, Sigma: 0.2, Attack Rate: 0.10944
# Omega: 1.4, Sigma: 0.225, Attack Rate: 0.10931999999999999
# Omega: 1.4, Sigma: 0.25, Attack Rate: 0.10864
# Omega: 1.4, Sigma: 0.275, Attack Rate: 0.10940000000000001
# Omega: 1.4, Sigma: 0.3, Attack Rate: 0.10242
# Omega: 1.4, Sigma: 0.325, Attack Rate: 0.1065
# Omega: 1.4, Sigma: 0.35, Attack Rate: 0.10926000000000001
# Omega: 1.4, Sigma: 0.375, Attack Rate: 0.10934
# Omega: 1.4, Sigma: 0.4, Attack Rate: 0.10084
# Omega: 1.4, Sigma: 0.425, Attack Rate: 0.10434
# Omega: 1.4, Sigma: 0.45, Attack Rate: 0.10937999999999999
# Omega: 1.4, Sigma: 0.475, Attack Rate: 0.10729999999999999
# Omega: 1.4, Sigma: 0.5, Attack Rate: 0.10506
# Omega: 1.5, Sigma: 0.0, Attack Rate: 0.12490000000000001
# Omega: 1.5, Sigma: 0.025, Attack Rate: 0.1279
# Omega: 1.5, Sigma: 0.05, Attack Rate: 0.11794
# Omega: 1.5, Sigma: 0.075, Attack Rate: 0.11381999999999999
# Omega: 1.5, Sigma: 0.1, Attack Rate: 0.11993999999999999
# Omega: 1.5, Sigma: 0.125, Attack Rate: 0.12056
# Omega: 1.5, Sigma: 0.15, Attack Rate: 0.11514
# Omega: 1.5, Sigma: 0.175, Attack Rate: 0.11162000000000001
# Omega: 1.5, Sigma: 0.2, Attack Rate: 0.11188
# Omega: 1.5, Sigma: 0.225, Attack Rate: 0.11492000000000001
# Omega: 1.5, Sigma: 0.25, Attack Rate: 0.11202
# Omega: 1.5, Sigma: 0.275, Attack Rate: 0.10656
# Omega: 1.5, Sigma: 0.3, Attack Rate: 0.10732
# Omega: 1.5, Sigma: 0.325, Attack Rate: 0.10316
# Omega: 1.5, Sigma: 0.35, Attack Rate: 0.11486
# Omega: 1.5, Sigma: 0.375, Attack Rate: 0.10772
# Omega: 1.5, Sigma: 0.4, Attack Rate: 0.10498
# Omega: 1.5, Sigma: 0.425, Attack Rate: 0.10466
# Omega: 1.5, Sigma: 0.45, Attack Rate: 0.1092
# Omega: 1.5, Sigma: 0.475, Attack Rate: 0.1021
# Omega: 1.5, Sigma: 0.5, Attack Rate: 0.10452
# Omega: 1.6, Sigma: 0.0, Attack Rate: 0.1389
# Omega: 1.6, Sigma: 0.025, Attack Rate: 0.1358
# Omega: 1.6, Sigma: 0.05, Attack Rate: 0.12193999999999999
# Omega: 1.6, Sigma: 0.075, Attack Rate: 0.11884
# Omega: 1.6, Sigma: 0.1, Attack Rate: 0.12226000000000001
# Omega: 1.6, Sigma: 0.125, Attack Rate: 0.11209999999999999
# Omega: 1.6, Sigma: 0.15, Attack Rate: 0.11394
# Omega: 1.6, Sigma: 0.175, Attack Rate: 0.1115
# Omega: 1.6, Sigma: 0.2, Attack Rate: 0.11295999999999999
# Omega: 1.6, Sigma: 0.225, Attack Rate: 0.11176
# Omega: 1.6, Sigma: 0.25, Attack Rate: 0.10496
# Omega: 1.6, Sigma: 0.275, Attack Rate: 0.10588
# Omega: 1.6, Sigma: 0.3, Attack Rate: 0.10994
# Omega: 1.6, Sigma: 0.325, Attack Rate: 0.11044
# Omega: 1.6, Sigma: 0.35, Attack Rate: 0.10456
# Omega: 1.6, Sigma: 0.375, Attack Rate: 0.09828
# Omega: 1.6, Sigma: 0.4, Attack Rate: 0.10765999999999999
# Omega: 1.6, Sigma: 0.425, Attack Rate: 0.10368000000000001
# Omega: 1.6, Sigma: 0.45, Attack Rate: 0.10708
# Omega: 1.6, Sigma: 0.475, Attack Rate: 0.10746
# Omega: 1.6, Sigma: 0.5, Attack Rate: 0.10048
# Omega: 1.7, Sigma: 0.0, Attack Rate: 0.13026
# Omega: 1.7, Sigma: 0.025, Attack Rate: 0.12922
# Omega: 1.7, Sigma: 0.05, Attack Rate: 0.12208
# Omega: 1.7, Sigma: 0.075, Attack Rate: 0.12254000000000001
# Omega: 1.7, Sigma: 0.1, Attack Rate: 0.11902
# Omega: 1.7, Sigma: 0.125, Attack Rate: 0.11504
# Omega: 1.7, Sigma: 0.15, Attack Rate: 0.1146
# Omega: 1.7, Sigma: 0.175, Attack Rate: 0.11328
# Omega: 1.7, Sigma: 0.2, Attack Rate: 0.1143
# Omega: 1.7, Sigma: 0.225, Attack Rate: 0.1065
# Omega: 1.7, Sigma: 0.25, Attack Rate: 0.11195999999999999
# Omega: 1.7, Sigma: 0.275, Attack Rate: 0.10352
# Omega: 1.7, Sigma: 0.3, Attack Rate: 0.10368000000000001
# Omega: 1.7, Sigma: 0.325, Attack Rate: 0.10962000000000001
# Omega: 1.7, Sigma: 0.35, Attack Rate: 0.10818000000000001
# Omega: 1.7, Sigma: 0.375, Attack Rate: 0.10882
# Omega: 1.7, Sigma: 0.4, Attack Rate: 0.10814
# Omega: 1.7, Sigma: 0.425, Attack Rate: 0.10588
# Omega: 1.7, Sigma: 0.45, Attack Rate: 0.10424
# Omega: 1.7, Sigma: 0.475, Attack Rate: 0.1016
# Omega: 1.7, Sigma: 0.5, Attack Rate: 0.10606
# Omega: 1.8, Sigma: 0.0, Attack Rate: 0.13284
# Omega: 1.8, Sigma: 0.025, Attack Rate: 0.1378
# Omega: 1.8, Sigma: 0.05, Attack Rate: 0.1264
# Omega: 1.8, Sigma: 0.075, Attack Rate: 0.13591999999999999
# Omega: 1.8, Sigma: 0.1, Attack Rate: 0.12448000000000001
# Omega: 1.8, Sigma: 0.125, Attack Rate: 0.11954000000000001
# Omega: 1.8, Sigma: 0.15, Attack Rate: 0.11544
# Omega: 1.8, Sigma: 0.175, Attack Rate: 0.11256000000000001
# Omega: 1.8, Sigma: 0.2, Attack Rate: 0.11058
# Omega: 1.8, Sigma: 0.225, Attack Rate: 0.10878
# Omega: 1.8, Sigma: 0.25, Attack Rate: 0.11468
# Omega: 1.8, Sigma: 0.275, Attack Rate: 0.11001999999999999
# Omega: 1.8, Sigma: 0.3, Attack Rate: 0.11062000000000001
# Omega: 1.8, Sigma: 0.325, Attack Rate: 0.10292
# Omega: 1.8, Sigma: 0.35, Attack Rate: 0.10906
# Omega: 1.8, Sigma: 0.375, Attack Rate: 0.10966
# Omega: 1.8, Sigma: 0.4, Attack Rate: 0.10672
# Omega: 1.8, Sigma: 0.425, Attack Rate: 0.10498
# Omega: 1.8, Sigma: 0.45, Attack Rate: 0.10031999999999999
# Omega: 1.8, Sigma: 0.475, Attack Rate: 0.10522
# Omega: 1.8, Sigma: 0.5, Attack Rate: 0.10412
# Omega: 1.9, Sigma: 0.0, Attack Rate: 0.13982
# Omega: 1.9, Sigma: 0.025, Attack Rate: 0.13552
# Omega: 1.9, Sigma: 0.05, Attack Rate: 0.1265
# Omega: 1.9, Sigma: 0.075, Attack Rate: 0.13241999999999998
# Omega: 1.9, Sigma: 0.1, Attack Rate: 0.12445999999999999
# Omega: 1.9, Sigma: 0.125, Attack Rate: 0.12140000000000001
# Omega: 1.9, Sigma: 0.15, Attack Rate: 0.11078
# Omega: 1.9, Sigma: 0.175, Attack Rate: 0.11284000000000001
# Omega: 1.9, Sigma: 0.2, Attack Rate: 0.11418
# Omega: 1.9, Sigma: 0.225, Attack Rate: 0.11412
# Omega: 1.9, Sigma: 0.25, Attack Rate: 0.11245999999999999
# Omega: 1.9, Sigma: 0.275, Attack Rate: 0.10682
# Omega: 1.9, Sigma: 0.3, Attack Rate: 0.10906
# Omega: 1.9, Sigma: 0.325, Attack Rate: 0.11137999999999999
# Omega: 1.9, Sigma: 0.35, Attack Rate: 0.10232
# Omega: 1.9, Sigma: 0.375, Attack Rate: 0.10732
# Omega: 1.9, Sigma: 0.4, Attack Rate: 0.1082
# Omega: 1.9, Sigma: 0.425, Attack Rate: 0.10722
# Omega: 1.9, Sigma: 0.45, Attack Rate: 0.10601999999999999
# Omega: 1.9, Sigma: 0.475, Attack Rate: 0.10790000000000001
# Omega: 1.9, Sigma: 0.5, Attack Rate: 0.10496
# Omega: 2.0, Sigma: 0.0, Attack Rate: 0.1373
# Omega: 2.0, Sigma: 0.025, Attack Rate: 0.1434
# Omega: 2.0, Sigma: 0.05, Attack Rate: 0.1308
# Omega: 2.0, Sigma: 0.075, Attack Rate: 0.12172
# Omega: 2.0, Sigma: 0.1, Attack Rate: 0.1254
# Omega: 2.0, Sigma: 0.125, Attack Rate: 0.11484
# Omega: 2.0, Sigma: 0.15, Attack Rate: 0.11974
# Omega: 2.0, Sigma: 0.175, Attack Rate: 0.11448
# Omega: 2.0, Sigma: 0.2, Attack Rate: 0.11212000000000001
# Omega: 2.0, Sigma: 0.225, Attack Rate: 0.10235999999999999
# Omega: 2.0, Sigma: 0.25, Attack Rate: 0.11156
# Omega: 2.0, Sigma: 0.275, Attack Rate: 0.10454000000000001
# Omega: 2.0, Sigma: 0.3, Attack Rate: 0.10288
# Omega: 2.0, Sigma: 0.325, Attack Rate: 0.10436
# Omega: 2.0, Sigma: 0.35, Attack Rate: 0.10443999999999999
# Omega: 2.0, Sigma: 0.375, Attack Rate: 0.10606
# Omega: 2.0, Sigma: 0.4, Attack Rate: 0.10878
# Omega: 2.0, Sigma: 0.425, Attack Rate: 0.1031
# Omega: 2.0, Sigma: 0.45, Attack Rate: 0.1037
# Omega: 2.0, Sigma: 0.475, Attack Rate: 0.10258
# Omega: 2.0, Sigma: 0.5, Attack Rate: 0.09926
# Data has been written.
